# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)

file = pd.read_csv('Resources/backer_info.csv')
backers_df = pd.DataFrame(file)
backers_df.head()
# Out:
#                                                                                           backer_info
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.
values = []
column_names = []

for i, row in backers_df.iterrows():
    data = row[0]
    converted_data = json.loads(data)
    columns = []
    rows = []
    for k,v in converted_data.items():
        columns.append(k)
        rows.append(v)
    column_names.append(columns)
    values.append(rows)

#backer_values = [json.loads(x[0]) for x in backers_df.values]
#backers_info_df = pd.DataFrame(backer_values)
#backers_info_df

backers_info_df = pd.DataFrame(values, columns = column_names[0])
backers_info_df
# Out:
#      backer_id  cf_id              name                  email
# 0        av166    968    Angelo Vincent      avincent@live.com
# 1        ha127    563     Hubert Arnold     harnold@yandex.com
# 2        lg794     65      Loris Goulet     lgoulet@yandex.com
# 3        tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4        lh506    563        Lexie Hunt         lhunt@live.com
# ...        ...    ...               ...                    ...
# 8170     st581     65   Serita Thebault   sthebault@yandex.com
# 8171     gf637    563   Glenn Foerstner   gfoerstner@yahoo.com
# 8172     rc983   1114       Robt Collin    rcollin@outlook.com
# 8173     cz381     65      Corina Zappa     czappa@outlook.com
# 8174     fg535     65     Freeman Gibbs     fgibbs@outlook.com
#
# [8175 rows x 4 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_info_df.to_csv('Resources/backers_data.csv', encoding = 'utf8')

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
file = pd.read_csv('Resources/backer_info.csv')
backer_info = pd.DataFrame(file)
backer_info
# Out:
#                                                                                              backer_info
# 0           {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1           {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2             {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3     {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4                  {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# ...                                                                                                  ...
# 8170     {"backer_id": "st581", "cf_id": 65, "name": "Serita Thebault", "email": "sthebault@yandex.com"}
# 8171    {"backer_id": "gf637", "cf_id": 563, "name": "Glenn Foerstner", "email": "gfoerstner@yahoo.com"}
# 8172        {"backer_id": "rc983", "cf_id": 1114, "name": "Robt Collin", "email": "rcollin@outlook.com"}
# 8173          {"backer_id": "cz381", "cf_id": 65, "name": "Corina Zappa", "email": "czappa@outlook.com"}
# 8174         {"backer_id": "fg535", "cf_id": 65, "name": "Freeman Gibbs", "email": "fgibbs@outlook.com"}
#
# [8175 rows x 1 columns]

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".
import re
backer_id = [re.findall("(?:\"backer_id\":\s\")([a-z0-9]{5})", x)[0] for x in backer_info["backer_info"]]
backer_id
# Out:
# ['av166',
#  'ha127',
#  'lg794',
#  'tb566',
#  'lh506',
#  'lh382',
#  'em444',
#  'at582',
#  'id772',
#  'lw275',
#  'ub509',
#  'ha915',
#  'bb881',
#  'mg332',
#  'kd700',
#  'as695',
#  'iv513',
#  'ab842',
#  're181',
#  'kn133',
#  'gj893',
#  'vp915',
#  'ja995',
#  'ga249',
#  'td403',
#  'tv463',
#  'mw606',
#  'hc648',
#  'ta379',
#  'tj583',
#  'tc559',
#  'ww629',
#  'jg155',
#  'jd328',
#  'ld239',
#  'cv918',
#  'kb145',
#  'dw578',
#  'ad511',
#  'db633',
#  'cr369',
#  'mr978',
#  'md167',
#  'jr877',
#  'om753',
#  'ng231',
#  'tl316',
#  'dl139',
#  'mw253',
#  'im424',
#  'mb131',
#  'nc240',
#  'ab318',
#  'af301',
#  'bl736',
#  'ar957',
#  'cb474',
#  'dv246',
#  'cj111',
#  'lh765',
#  'wh697',
#  'eb714',
#  'ec356',
#  'yh129',
#  'as494',
#  'lb146',
#  'cc470',
#  'mm239',
#  'dg360',
#  'rh399',
#  'hr430',
#  'ar829',
#  'sw301',
#  'rr355',
#  'zc515',
#  'gp101',
#  'bm741',
#  'jd148',
#  'mm632',
#  'ls884',
#  'sp364',
#  'hh963',
#  'sb272',
#  'et566',
#  'sd421',
#  'tg563',
#  'kc571',
#  'sd121',
#  'sk744',
#  'km642',
#  'fu320',
#  'ld180',
#  'ds377',
#  'bb692',
#  'wd557',
#  'jd905',
#  'dd770',
#  'cv698',
#  'cn307',
#  'eb198',
#  'am869',
#  'gr400',
#  'az657',
#  'kc598',
#  'lb588',
#  'rl866',
#  'jf340',
#  'tb384',
#  'dg290',
#  'rr518',
#  'sh779',
#  'lw525',
#  'sl474',
#  'dp154',
#  'id770',
#  'ek669',
#  'eb945',
#  'ag917',
#  'ac437',
#  'sf583',
#  'sa973',
#  'kc836',
#  'bt844',
#  'mf392',
#  'dh568',
#  'iv880',
#  'gl219',
#  'kb890',
#  'jf901',
#  'ja340',
#  'ar906',
#  'dc579',
#  'gg660',
#  'db112',
#  'ld487',
#  'bj475',
#  'mc838',
#  'he768',
#  'pm973',
#  'bf986',
#  'sb322',
#  'ps571',
#  'mb333',
#  'ab290',
#  'jm190',
#  'rg933',
#  'ik787',
#  'rl982',
#  'ac179',
#  'eg193',
#  'fl258',
#  'mb203',
#  'en399',
#  'mr756',
#  'sc271',
#  'xg684',
#  'ab829',
#  'fd404',
#  'rm849',
#  'lr658',
#  'sh994',
#  'zv654',
#  'hb861',
#  'hb280',
#  'be560',
#  'lh820',
#  'zp659',
#  'de758',
#  'jb896',
#  'wb355',
#  'rd560',
#  'er574',
#  'jc163',
#  'kb942',
#  'af969',
#  'bp212',
#  'tc947',
#  'ak106',
#  'mr294',
#  'bb365',
#  'bj274',
#  'qw345',
#  'ra925',
#  'pg824',
#  'ef414',
#  'rp650',
#  'se972',
#  'sd958',
#  'mb304',
#  'lr409',
#  'fm559',
#  'wd714',
#  'ls638',
#  'am362',
#  'ta190',
#  'rb753',
#  'cc594',
#  'vh915',
#  'og539',
#  'dd470',
#  'ap718',
#  'vw158',
#  'fh696',
#  'df617',
#  'jv716',
#  'tc807',
#  'me460',
#  'kp942',
#  'xp438',
#  'af564',
#  'wn746',
#  'ad641',
#  'rs660',
#  'dp520',
#  'me520',
#  'es977',
#  'sd883',
#  'tb283',
#  'eb415',
#  'fb116',
#  'jb391',
#  'ac624',
#  'kc104',
#  'dg582',
#  'mb933',
#  'em898',
#  'tw982',
#  'ab575',
#  'dg744',
#  'cj442',
#  'lo117',
#  'bg270',
#  'jc692',
#  'jf750',
#  'lr317',
#  'cp253',
#  'vv330',
#  'ch724',
#  'dm121',
#  'lc141',
#  'am966',
#  'ab249',
#  'mb828',
#  'pu317',
#  'cb515',
#  'so203',
#  'aa284',
#  'sc143',
#  'je217',
#  'ke511',
#  'oa673',
#  'sc432',
#  'aj655',
#  'jp351',
#  'lj758',
#  'ps794',
#  'nb202',
#  'gp356',
#  'rb945',
#  'gw991',
#  'gb896',
#  'jm345',
#  'ma565',
#  'oh728',
#  'dg119',
#  'kd744',
#  'ww138',
#  'gb135',
#  'lp541',
#  'hm752',
#  'ib452',
#  'fc303',
#  'kb141',
#  'is909',
#  'hv133',
#  'nm163',
#  'cs899',
#  'lh190',
#  'as260',
#  'db149',
#  'cg952',
#  'tm490',
#  'lt569',
#  'ce212',
#  'sr285',
#  'tc231',
#  'll471',
#  'aa130',
#  'sb241',
#  'lb909',
#  'lw976',
#  'ab143',
#  'cg893',
#  'nl492',
#  'nc285',
#  'ct703',
#  'aw876',
#  'af506',
#  'es282',
#  'co633',
#  'mh163',
#  'pc978',
#  'gc386',
#  'nl252',
#  'rb829',
#  'gl884',
#  'og404',
#  'kr745',
#  'jc104',
#  'th958',
#  'jb207',
#  'lm386',
#  'ic277',
#  'ab714',
#  'jm813',
#  'ma226',
#  'lm154',
#  'pp209',
#  'ss320',
#  'lb805',
#  'sf196',
#  'jc350',
#  'bh958',
#  'vp800',
#  'ec148',
#  'ha431',
#  'sw972',
#  'sb891',
#  'sf735',
#  'mp538',
#  'cf904',
#  'gs818',
#  'ra782',
#  'yc752',
#  'le377',
#  'ja139',
#  'jf881',
#  'am638',
#  'rh663',
#  'dl438',
#  'je184',
#  'xg938',
#  'mg208',
#  'ag672',
#  'sc991',
#  'ar456',
#  'an122',
#  'mh749',
#  'ac765',
#  'ln560',
#  'dm881',
#  'wm699',
#  'ca628',
#  'ls538',
#  'kr958',
#  'ad265',
#  'am627',
#  'rp666',
#  'rs221',
#  'ma490',
#  'xd210',
#  'mc413',
#  'ss568',
#  'dr174',
#  'vb927',
#  'ms327',
#  'lf675',
#  'hb499',
#  'lb187',
#  'um200',
#  'gh932',
#  'kl672',
#  'ab491',
#  'bb348',
#  'jv337',
#  'lh149',
#  'kw599',
#  'mh683',
#  'bm342',
#  'il539',
#  'jl327',
#  'wf249',
#  'ba539',
#  'sj553',
#  'gb371',
#  'hm715',
#  'ec905',
#  'lw634',
#  'dh507',
#  'mr622',
#  'gs461',
#  'gb648',
#  'eo125',
#  'rb185',
#  'og865',
#  'tr733',
#  'ac323',
#  'lo326',
#  'hc889',
#  'hv904',
#  'md370',
#  'sb514',
#  'sf324',
#  'eb537',
#  'bn189',
#  'sc931',
#  'th234',
#  'lb460',
#  'sp161',
#  'bm476',
#  'ta391',
#  'bm966',
#  'nm952',
#  'rg418',
#  'rm381',
#  'ab162',
#  'gf246',
#  'ch750',
#  'jg803',
#  'pl955',
#  'bc578',
#  'np469',
#  'nj734',
#  'as672',
#  'lg912',
#  'rm719',
#  'kh931',
#  'ml523',
#  'df670',
#  'cs996',
#  'wh607',
#  'jp523',
#  'rw116',
#  'md744',
#  'df975',
#  'rl203',
#  'ab776',
#  'th710',
#  'if257',
#  'ls716',
#  'bh265',
#  'bb194',
#  'sa754',
#  'jb318',
#  'ls852',
#  'mf855',
#  'sg584',
#  'jg665',
#  'ra144',
#  'ad490',
#  'ab679',
#  'mm395',
#  'tp337',
#  'li108',
#  'mb156',
#  'jc698',
#  'rm314',
#  'bm559',
#  'rj697',
#  'eu931',
#  'tf166',
#  'lb900',
#  'kp905',
#  'bm614',
#  'km622',
#  'bw202',
#  'lb585',
#  'ah247',
#  'db600',
#  'sb809',
#  'gm424',
#  'ch866',
#  'bh772',
#  'ms428',
#  'ib835',
#  'mc605',
#  'dg103',
#  'sd529',
#  'ac329',
#  'nw931',
#  'ma304',
#  'da603',
#  'mg138',
#  'ac101',
#  'nw842',
#  'bh208',
#  'bh308',
#  'mm312',
#  'lh971',
#  'se114',
#  'bh284',
#  'kc189',
#  'rf869',
#  'mg199',
#  'lb962',
#  'db172',
#  'sf770',
#  'np731',
#  'ma765',
#  'at430',
#  'nh902',
#  'mr954',
#  'ad976',
#  'ea132',
#  'dg632',
#  'ap998',
#  'tp324',
#  'ra997',
#  'dl230',
#  'rh438',
#  'ra521',
#  'ct232',
#  'pk248',
#  'sd478',
#  'gd604',
#  'vb562',
#  'rt274',
#  'wv265',
#  'vv260',
#  'jr651',
#  'is444',
#  'kb607',
#  'll538',
#  'mc191',
#  'eb575',
#  'wl942',
#  'st133',
#  'cl196',
#  'ws476',
#  'cb812',
#  'cb535',
#  'jc627',
#  'kg987',
#  'ec579',
#  'ar298',
#  'af221',
#  'sj329',
#  'dg117',
#  'dc370',
#  'zb278',
#  'cl760',
#  'jc156',
#  'as179',
#  'ip107',
#  'rc580',
#  'fs682',
#  'nv909',
#  'ms790',
#  'od761',
#  'mf156',
#  'as164',
#  'vj589',
#  'lb130',
#  'sl700',
#  'mc819',
#  'rm952',
#  'pg461',
#  'nh583',
#  'pb241',
#  'gl120',
#  'la505',
#  'aw399',
#  're335',
#  'bb962',
#  'ka827',
#  'vw359',
#  'tb824',
#  'hc237',
#  'as145',
#  'hw326',
#  'ap397',
#  'ss188',
#  'el440',
#  'aa862',
#  'eg547',
#  'bb801',
#  'le995',
#  'md256',
#  'mj723',
#  'jf335',
#  'os747',
#  'hw746',
#  'cd245',
#  'ld541',
#  'rh153',
#  'bh368',
#  'lb158',
#  'cs978',
#  'mf368',
#  'wd850',
#  'eb501',
#  'ac560',
#  'ra717',
#  'kb147',
#  'ab885',
#  'sm804',
#  'nn896',
#  'nh517',
#  'ks751',
#  'op970',
#  'fl206',
#  'vb725',
#  'ah650',
#  'mp562',
#  'ss542',
#  'uy666',
#  'rs149',
#  'nc808',
#  'cf496',
#  'ia565',
#  'jp782',
#  'mh715',
#  'nt342',
#  'mr456',
#  'ca746',
#  'cm505',
#  'sd889',
#  'bs934',
#  'ra567',
#  'rl204',
#  'cc259',
#  'sb553',
#  'cg125',
#  'qb899',
#  'ff220',
#  'hg196',
#  'sb625',
#  'pt119',
#  'lc553',
#  'rc275',
#  'md340',
#  'cc173',
#  'gd567',
#  'mb618',
#  'gc276',
#  'dc510',
#  'ye524',
#  'yd412',
#  'if272',
#  'lc645',
#  'ef207',
#  'dg835',
#  'hb488',
#  'lm201',
#  'pc883',
#  'kw981',
#  'mz620',
#  'hg644',
#  'es569',
#  'wg259',
#  'es891',
#  'pn152',
#  'em884',
#  'mj677',
#  'as403',
#  'sn755',
#  'cd582',
#  'rb866',
#  'jg570',
#  'tm126',
#  'kh370',
#  'cd370',
#  'al498',
#  'gb805',
#  'gh546',
#  'mv360',
#  'sm882',
#  'nl941',
#  'nc986',
#  'ej494',
#  'ib275',
#  'fm950',
#  'uh130',
#  'nl576',
#  'ba847',
#  'hk769',
#  'ce152',
#  'ds307',
#  'ap892',
#  'al282',
#  'ch210',
#  'eh215',
#  'eb850',
#  'dg270',
#  'ff566',
#  'am384',
#  'gz133',
#  'sb280',
#  'au559',
#  'ah481',
#  'rf512',
#  'ag245',
#  'gw953',
#  'el392',
#  'ng985',
#  'wj382',
#  'ba575',
#  'eg561',
#  'lm964',
#  'sb431',
#  'do639',
#  'sk460',
#  'rg322',
#  'dd765',
#  'gr869',
#  'kb523',
#  'lm458',
#  'el995',
#  'ag183',
#  'ld726',
#  'kr437',
#  'da484',
#  'an639',
#  'mp433',
#  'be701',
#  'jb183',
#  'kh101',
#  'mf245',
#  'js289',
#  'up926',
#  'ld381',
#  'mc308',
#  'lc522',
#  'dp392',
#  'ac362',
#  'nd561',
#  'fh314',
#  'sc323',
#  'ec717',
#  'rl688',
#  'uy750',
#  'nk412',
#  'ap726',
#  'dr773',
#  'ag727',
#  'ob153',
#  'td769',
#  'cf164',
#  'xb511',
#  'mg697',
#  'ab343',
#  'wr830',
#  'js847',
#  'rg452',
#  'lr201',
#  'jq602',
#  'vw742',
#  'ma775',
#  'ms114',
#  'bh610',
#  'ae528',
#  'ec370',
#  'mh322',
#  'aa738',
#  'cq458',
#  'lp143',
#  'ip230',
#  'cw810',
#  'rd198',
#  'ic683',
#  'wm615',
#  'ls953',
#  'fj322',
#  'ld699',
#  'pm788',
#  'dm569',
#  'rt816',
#  'jd575',
#  'zb283',
#  'jp468',
#  'cg793',
#  'gp711',
#  'pc765',
#  'sl534',
#  'yv989',
#  'mf798',
#  'td407',
#  'tg953',
#  'kc148',
#  'cs309',
#  'mt354',
#  'hw981',
#  'sk249',
#  'ud288',
#  'lb533',
#  'bc627',
#  'sv404',
#  'ab517',
#  'ta342',
#  'ja317',
#  'rc984',
#  'mc890',
#  'lp216',
#  'fo113',
#  'mb739',
#  'gp648',
#  'mr769',
#  'kp887',
#  'lb922',
#  'zr677',
#  'bm219',
#  'ah632',
#  'tr889',
#  'oh928',
#  'rb570',
#  'rb669',
#  'ab395',
#  'cj317',
#  'tr126',
#  'bh500',
#  'nw754',
#  'nb415',
#  'ic294',
#  'jr674',
#  'oh931',
#  'jc510',
#  'gg408',
#  'cb611',
#  'wj450',
#  'kb366',
#  'id932',
#  'pw185',
#  'md753',
#  'db519',
#  'vb592',
#  'tl538',
#  'se137',
#  'jf485',
#  'nh755',
#  'ak859',
#  'tt425',
#  'cm443',
#  'ih676',
#  'mb336',
#  'da354',
#  'na435',
#  'ar819',
#  'pw829',
#  'hb895',
#  'mp964',
#  'em597',
#  'cr743',
#  'sb664',
#  'nc766',
#  'iv865',
#  'kr139',
#  'kp261',
#  'hb804',
#  'mb384',
#  'lp884',
#  'ae594',
#  'ta987',
#  'kd374',
#  'lt755',
#  'ds585',
#  'hm748',
#  'bm320',
#  'mm149',
#  'nb639',
#  'cw520',
#  'lb450',
#  'ap187',
#  'gt421',
#  'ep895',
#  'wa701',
#  'yf490',
#  'fl110',
#  'lb870',
#  'dg363',
#  'kb110',
#  'fb424',
#  'lw574',
#  'ae918',
#  'ar961',
#  'mt716',
#  'dk254',
#  'am874',
#  'cr525',
#  'wc513',
#  'bc364',
#  'cf230',
#  'jn670',
#  'bg581',
#  'sh228',
#  'mj954',
#  'jm101',
#  'nf369',
#  'cg631',
#  'lp218',
#  'of784',
#  'ds610',
#  'bb467',
#  'bv607',
#  'cp794',
#  'aw326',
#  'ms559',
#  'rl122',
#  'mc544',
#  'mv762',
#  'rg638',
#  'eb865',
#  'eb701',
#  'lb178',
#  'aa484',
#  'sh493',
#  'rg624',
#  'am644',
#  'ka406',
#  'lb213',
#  'wh558',
#  'jo527',
#  'hd242',
#  'dc144',
#  'gh229',
#  'ra187',
#  'lg556',
#  'fh102',
#  'lh128',
#  'ah861',
#  'ht719',
#  'll609',
#  'vr608',
#  'dd769',
#  'cv209',
#  'fm638',
#  'aj578',
#  'ps285',
#  'db210',
#  'au377',
#  'cg265',
#  'ds180',
#  'rt281',
#  'ph749',
#  'tc503',
#  'mb313',
#  'sl362',
#  'uh381',
#  'km314',
#  'eb969',
#  'tb251',
#  'ld647',
#  'rl209',
#  'mt873',
#  'lf516',
#  'ta679',
#  'sd882',
#  'dp941',
#  'ms270',
#  'jf193',
#  'db832',
#  'lc293',
#  'sc440',
#  'na467',
#  'mp998',
#  'rw179',
#  'rd613',
#  'dc677',
#  'km838',
#  'ha922',
#  'ma291',
#  'ls903',
#  'dl984',
#  'fj308',
#  'pf542',
#  'mc619',
#  'lc435',
#  'kr813',
#  'eb667',
#  'sc261',
#  'ht501',
#  'cf209',
#  'th306',
#  'uf135',
#  'tt696',
#  'mr372',
#  'lb930',
#  'ap347',
#  'tb394',
#  'rn232',
#  'df983',
#  'ld418',
#  'yv730',
#  'ea712',
#  'ky770',
#  'jc963',
#  'la958',
#  'yg885',
#  'ah815',
#  'cm949',
#  'dt412',
#  'zm103',
#  'yh430',
#  'sb943',
#  'ot297',
#  'en876',
#  'lp640',
#  'es903',
#  'nr568',
#  'nb860',
#  'hb501',
#  ...]

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".
cf_id = [re.findall("(?:\"cf_id\":\s)([\d]+)", x)[0] for x in backer_info["backer_info"]]
cf_id
# Out:
# ['968',
#  '563',
#  '65',
#  '563',
#  '563',
#  '563',
#  '563',
#  '1572',
#  '1911',
#  '65',
#  '65',
#  '1572',
#  '968',
#  '65',
#  '1572',
#  '563',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '948',
#  '563',
#  '563',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '563',
#  '1572',
#  '65',
#  '65',
#  '1572',
#  '1911',
#  '65',
#  '968',
#  '563',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '1572',
#  '65',
#  '1114',
#  '65',
#  '563',
#  '968',
#  '65',
#  '968',
#  '1572',
#  '1572',
#  '65',
#  '563',
#  '65',
#  '968',
#  '1572',
#  '563',
#  '563',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '563',
#  '563',
#  '563',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '968',
#  '65',
#  '65',
#  '1114',
#  '1572',
#  '65',
#  '968',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '1911',
#  '65',
#  '65',
#  '563',
#  '65',
#  '65',
#  '238',
#  '968',
#  '1572',
#  '65',
#  '1911',
#  '563',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '968',
#  '65',
#  '563',
#  '65',
#  '238',
#  '65',
#  '65',
#  '1114',
#  '563',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '968',
#  '1572',
#  '1572',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '563',
#  '1572',
#  '1572',
#  '968',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '238',
#  '65',
#  '1114',
#  '65',
#  '968',
#  '563',
#  '1572',
#  '563',
#  '65',
#  '563',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '563',
#  '1572',
#  '1114',
#  '65',
#  '238',
#  '65',
#  '1572',
#  '65',
#  '1114',
#  '563',
#  '1572',
#  '65',
#  '1572',
#  '1572',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '968',
#  '65',
#  '238',
#  '1114',
#  '65',
#  '65',
#  '563',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '563',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1911',
#  '238',
#  '1572',
#  '2284',
#  '968',
#  '65',
#  '65',
#  '563',
#  '1572',
#  '563',
#  '1572',
#  '1114',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '3138',
#  '65',
#  '65',
#  '1572',
#  '1572',
#  '563',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '968',
#  '65',
#  '1572',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '968',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '563',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '563',
#  '968',
#  '65',
#  '968',
#  '968',
#  '1572',
#  '1572',
#  '968',
#  '1572',
#  '65',
#  '910',
#  '563',
#  '1911',
#  '65',
#  '1572',
#  '968',
#  '65',
#  '1572',
#  '563',
#  '65',
#  '1911',
#  '65',
#  '1114',
#  '65',
#  '968',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '563',
#  '65',
#  '65',
#  '65',
#  '2284',
#  '2882',
#  '968',
#  '65',
#  '563',
#  '968',
#  '910',
#  '1114',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '1572',
#  '563',
#  '65',
#  '65',
#  '65',
#  '65',
#  '2882',
#  '1114',
#  '1572',
#  '65',
#  '65',
#  '1911',
#  '238',
#  '968',
#  '65',
#  '65',
#  '968',
#  '968',
#  '2488',
#  '238',
#  '1114',
#  '65',
#  '1114',
#  '1572',
#  '968',
#  '1572',
#  '1114',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '1572',
#  '1114',
#  '563',
#  '1572',
#  '1572',
#  '1572',
#  '1911',
#  '563',
#  '968',
#  '65',
#  '1114',
#  '65',
#  '238',
#  '1114',
#  '65',
#  '563',
#  '65',
#  '65',
#  '238',
#  '65',
#  '65',
#  '65',
#  '563',
#  '1114',
#  '65',
#  '1114',
#  '1114',
#  '563',
#  '65',
#  '1572',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '563',
#  '1572',
#  '563',
#  '563',
#  '65',
#  '1911',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '563',
#  '1572',
#  '2882',
#  '65',
#  '3138',
#  '65',
#  '65',
#  '1114',
#  '563',
#  '65',
#  '1572',
#  '563',
#  '563',
#  '1572',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '563',
#  '563',
#  '1572',
#  '563',
#  '563',
#  '65',
#  '1911',
#  '563',
#  '65',
#  '1114',
#  '1572',
#  '1572',
#  '968',
#  '65',
#  '1114',
#  '65',
#  '1114',
#  '563',
#  '238',
#  '563',
#  '1572',
#  '1911',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '1114',
#  '1114',
#  '563',
#  '968',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '1114',
#  '1114',
#  '65',
#  '1114',
#  '968',
#  '238',
#  '65',
#  '563',
#  '65',
#  '65',
#  '563',
#  '65',
#  '1572',
#  '1572',
#  '968',
#  '65',
#  '968',
#  '65',
#  '563',
#  '65',
#  '968',
#  '1572',
#  '238',
#  '948',
#  '1572',
#  '65',
#  '1572',
#  '968',
#  '563',
#  '65',
#  '1572',
#  '65',
#  '563',
#  '1572',
#  '563',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '1572',
#  '1572',
#  '1572',
#  '1114',
#  '65',
#  '563',
#  '65',
#  '563',
#  '65',
#  '65',
#  '563',
#  '65',
#  '563',
#  '1911',
#  '65',
#  '65',
#  '65',
#  '968',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '563',
#  '65',
#  '563',
#  '1114',
#  '65',
#  '65',
#  '1114',
#  '1572',
#  '563',
#  '65',
#  '65',
#  '65',
#  '968',
#  '65',
#  '65',
#  '65',
#  '968',
#  '563',
#  '563',
#  '563',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '238',
#  '1911',
#  '1572',
#  '238',
#  '65',
#  '1572',
#  '65',
#  '948',
#  '563',
#  '65',
#  '65',
#  '238',
#  '65',
#  '65',
#  '968',
#  '1911',
#  '65',
#  '968',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '968',
#  '65',
#  '1572',
#  '1114',
#  '1572',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '563',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '563',
#  '2284',
#  '65',
#  '1572',
#  '65',
#  '910',
#  '3138',
#  '2510',
#  '65',
#  '968',
#  '1572',
#  '968',
#  '65',
#  '1114',
#  '238',
#  '563',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '968',
#  '968',
#  '1572',
#  '563',
#  '65',
#  '65',
#  '968',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '2882',
#  '65',
#  '65',
#  '238',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '948',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '563',
#  '1114',
#  '65',
#  '948',
#  '65',
#  '1114',
#  '1572',
#  '1572',
#  '65',
#  '65',
#  '1114',
#  '1114',
#  '1114',
#  '968',
#  '1572',
#  '65',
#  '65',
#  '563',
#  '65',
#  '65',
#  '563',
#  '563',
#  '563',
#  '65',
#  '968',
#  '1572',
#  '65',
#  '968',
#  '65',
#  '1572',
#  '2488',
#  '910',
#  '65',
#  '65',
#  '968',
#  '2284',
#  '968',
#  '563',
#  '910',
#  '563',
#  '65',
#  '1572',
#  '563',
#  '65',
#  '1114',
#  '1911',
#  '563',
#  '1911',
#  '968',
#  '65',
#  '1572',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '1114',
#  '1572',
#  '65',
#  '1114',
#  '65',
#  '563',
#  '1572',
#  '65',
#  '968',
#  '1572',
#  '1572',
#  '1114',
#  '1114',
#  '1114',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '910',
#  '2510',
#  '65',
#  '563',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '563',
#  '65',
#  '563',
#  '65',
#  '1572',
#  '65',
#  '1572',
#  '1114',
#  '563',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '563',
#  '65',
#  '65',
#  '563',
#  '1572',
#  '1114',
#  '1911',
#  '563',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '1114',
#  '1114',
#  '1572',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '910',
#  '910',
#  '1114',
#  '1114',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '563',
#  '563',
#  '1114',
#  '1572',
#  '65',
#  '563',
#  '563',
#  '968',
#  '65',
#  '968',
#  '910',
#  '1572',
#  '1114',
#  '65',
#  '563',
#  '65',
#  '563',
#  '65',
#  '563',
#  '65',
#  '968',
#  '1572',
#  '65',
#  '238',
#  '968',
#  '65',
#  '563',
#  '65',
#  '563',
#  '563',
#  '65',
#  '65',
#  '65',
#  '968',
#  '65',
#  '563',
#  '1572',
#  '968',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '948',
#  '563',
#  '1114',
#  '1572',
#  '2882',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '968',
#  '65',
#  '1572',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '563',
#  '1114',
#  '1572',
#  '65',
#  '968',
#  '563',
#  '65',
#  '65',
#  '968',
#  '1114',
#  '65',
#  '65',
#  '968',
#  '1572',
#  '65',
#  '65',
#  '968',
#  '563',
#  '1114',
#  '968',
#  '563',
#  '65',
#  '968',
#  '563',
#  '563',
#  '1572',
#  '1114',
#  '1114',
#  '65',
#  '65',
#  '238',
#  '1572',
#  '65',
#  '910',
#  '1911',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '563',
#  '65',
#  '65',
#  '968',
#  '1572',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '563',
#  '238',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '1114',
#  '968',
#  '968',
#  '1572',
#  '1114',
#  '65',
#  '1114',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '1114',
#  '968',
#  '563',
#  '968',
#  '65',
#  '948',
#  '65',
#  '563',
#  '65',
#  '563',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '910',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '1114',
#  '968',
#  '65',
#  '65',
#  '563',
#  '65',
#  '1114',
#  '1114',
#  '1114',
#  '948',
#  '238',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '1114',
#  '968',
#  '1572',
#  '563',
#  '65',
#  '968',
#  '968',
#  '968',
#  '1572',
#  '65',
#  '1911',
#  '1572',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '2882',
#  '1572',
#  '968',
#  '1114',
#  '1572',
#  '968',
#  '1572',
#  '563',
#  '968',
#  '65',
#  '1114',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '968',
#  '968',
#  '65',
#  '65',
#  '65',
#  '65',
#  '563',
#  '1911',
#  '65',
#  '1572',
#  '1572',
#  '65',
#  '563',
#  '65',
#  '968',
#  '1114',
#  '65',
#  '563',
#  '968',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1572',
#  '65',
#  '1572',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '563',
#  '563',
#  '65',
#  '563',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '65',
#  '1114',
#  '65',
#  '65',
#  '968',
#  '65',
#  '563',
#  '968',
#  '1572',
#  '65',
#  ...]

# %%
# Extract the name from the backer_info column and add it as a new column called "name".
name = [re.findall("(?:\"name\":\s\")([a-zA-Z]+\s[a-zA-Z]+)",x)[0] for x in backer_info["backer_info"]]
name
# Out:
# ['Angelo Vincent',
#  'Hubert Arnold',
#  'Loris Goulet',
#  'Teodora Brunelli',
#  'Lexie Hunt',
#  'Lambert Huber',
#  'Emmy Morin',
#  'Armonda Trani',
#  'Ilana Duke',
#  'Leigha Wright',
#  'Uwe Becker',
#  'Hawa Audy',
#  'Bia Bonura',
#  'Michel Garner',
#  'Karole Dunn',
#  'Arndt Schreiber',
#  'Imen Villeneuve',
#  'Alcina Bonadonna',
#  'Raelene Espinoza',
#  'Kati Nash',
#  'Georg Jager',
#  'Virgilio Paolella',
#  'Jerrica Avila',
#  'Gianni Achterberg',
#  'Timoteo Dion',
#  'Teodoro Verno',
#  'Morris Waller',
#  'Hans Chen',
#  'Trilby Auer',
#  'Theola Jodoin',
#  'Tova Capri',
#  'Wanda Walton',
#  'Justine Gill',
#  'Julee Doyle',
#  'Lisbeth Deliso',
#  'Carl Valdez',
#  'Kelyan Butler',
#  'Donat Weber',
#  'Alethia Delorme',
#  'Darrell Bernardi',
#  'Carina Reeves',
#  'Marvin Ruiz',
#  'Mariabella Duerr',
#  'Jeni Ricco',
#  'Otto Munoz',
#  'Nesrine Gensch',
#  'Tullio Lejeune',
#  'Dreama Lonardo',
#  'Maryrose West',
#  'Irina Mays',
#  'Marcelo Brose',
#  'Nestor Coutant',
#  'Aloysius Braun',
#  'Amos Ferre',
#  'Brigitte Lynch',
#  'Alegra Ramsey',
#  'Conchita Beitel',
#  'Donnie Vernet',
#  'Cyril Jones',
#  'Lucinda Hays',
#  'Walter Hermann',
#  'Emil Blanc',
#  'Eldwin Cesare',
#  'Yusuf Hudson',
#  'Arrigo Salazar',
#  'Levi Beck',
#  'Celinda Caillet',
#  'Marcus Medici',
#  'Daysi Gamble',
#  'Rory Hildebrand',
#  'Heini Raffin',
#  'Anna Randall',
#  'Sharmaine Weber',
#  'Ranee Renault',
#  'Zak Cianciola',
#  'Granville Potts',
#  'Bo Marsh',
#  'Jay Duerr',
#  'Milla Morin',
#  'Leanne Savage',
#  'Silvana Patton',
#  'Harvey Hoch',
#  'Seth Berthier',
#  'Eugen Trani',
#  'Santina Dieter',
#  'Trinh Gregoire',
#  'Karin Celano',
#  'Sofia Decker',
#  'Sherise Keller',
#  'Kirby Michel',
#  'Florentine Ungaro',
#  'Louise Dejesus',
#  'Daniele Suarez',
#  'Beckie Buchholz',
#  'William Dickson',
#  'Jolie Daugherty',
#  'Detta Dressler',
#  'Clifton Villette',
#  'Cythia Netti',
#  'Elsbeth Butler',
#  'Ambrine Mann',
#  'Gerald Robert',
#  'Assunta Zezza',
#  'Kerstin Campbell',
#  'Lino Brock',
#  'Rubie Levasseur',
#  'Johann Flowers',
#  'Thibaud Bullock',
#  'Dan Gallois',
#  'Rolf Richards',
#  'Selyan Hoffman',
#  'Lucca Weber',
#  'Sydney Louvet',
#  'Dusty Paola',
#  'Ilario Dressler',
#  'Emile Khan',
#  'Elliot Bonomo',
#  'Arvin Golden',
#  'Ampelio Cabrera',
#  'Somer Fuhrmann',
#  'Shanti Allard',
#  'Konstanze Caroselli',
#  'Bellarmine Taylor',
#  'Matthew Fischer',
#  'Dan Hoffmann',
#  'Imelda Vallee',
#  'Giancarlo Lindsey',
#  'Kris Brennan',
#  'Johnnie Fux',
#  'Janeth Adam',
#  'Agata Rosa',
#  'Dennise Cabrera',
#  'Garret Geier',
#  'Delia Beguin',
#  'Louanne Damiani',
#  'Bronze Jenkins',
#  'Mila Coffey',
#  'Hank Essert',
#  'Paulina Marais',
#  'Beatrice Fulco',
#  'Sudie Burgess',
#  'Prince Suarez',
#  'Mitzi Biermann',
#  'Aminata Bru',
#  'Jina Magrino',
#  'Rosena Gould',
#  'Issac Kline',
#  'Roderica Lehmann',
#  'Ariah Comte',
#  'Ellis Gamble',
#  'Friedrich Lott',
#  'Marilou Beutel',
#  'Elene Navarro',
#  'Mac Raffin',
#  'Shona Carr',
#  'Ximena Guy',
#  'Arnaud Becker',
#  'Fiore Desautels',
#  'Robby Mccray',
#  'Louis Rush',
#  'Serena Holzknecht',
#  'Zan Verdier',
#  'Hipolito Baldocchi',
#  'Hollis Barnett',
#  'Barend Edwards',
#  'Loane Holst',
#  'Zeno Pruneau',
#  'Devon Epifano',
#  'Jarrett Barrera',
#  'Walburg Burris',
#  'Raffaela Darras',
#  'Eli Resta',
#  'Jin Chen',
#  'Katja Butler',
#  'Allegra Fiedler',
#  'Benton Pereira',
#  'Tesha Carpinello',
#  'Anneli Kaufman',
#  'Merle Rowe',
#  'Bev Bellotti',
#  'Blake Jenkins',
#  'Qiana Washington',
#  'Rayane Adam',
#  'Petronella Guilbaud',
#  'Elodia Forgione',
#  'Ryan Potts',
#  'Sigmund Everett',
#  'Serafina Desroches',
#  'Murray Barrese',
#  'Luis Roberts',
#  'Felicia Mcneil',
#  'Willette Dattoli',
#  'Lucas Stephens',
#  'Amo Moses',
#  'Tandy Acker',
#  'Rolf Biron',
#  'Catharina Cappella',
#  'Virgilio Hyde',
#  'Ollie Gwerder',
#  'Daniela Demers',
#  'Angel Peragine',
#  'Vicenzo Wells',
#  'Fernanda Hodges',
#  'Darrin Fiedler',
#  'Janine Veronesi',
#  'Terenzio Carver',
#  'Magali Eilerts',
#  'Kimber Puech',
#  'Xenia Pergola',
#  'Arlena Fox',
#  'Wilfred Nazzaro',
#  'Angelina Decker',
#  'Ressie Schneider',
#  'Daine Pruneau',
#  'Marius Emilio',
#  'Emily Stout',
#  'Shaunna Dreher',
#  'Toi Briere',
#  'Eliodoro Black',
#  'Faustino Burgstaller',
#  'Jeramy Benard',
#  'Annika Curtis',
#  'Kelia Campbell',
#  'Dario Gerst',
#  'Maryetta Bussa',
#  'Emerich Mccoy',
#  'Timothe Wilder',
#  'Amadore Breitbarth',
#  'Dave Gaillard',
#  'Catrin Joseph',
#  'Laverne Ortega',
#  'Bulah Guay',
#  'Jae Castellucci',
#  'Joseph Freeman',
#  'Lena Robbins',
#  'Charley Petitjean',
#  'Veronika Vesco',
#  'Calandra Hofmeister',
#  'Devon Marques',
#  'Leon Carson',
#  'Adelrico Meadows',
#  'Adel Becke',
#  'Mariya Babin',
#  'Peg Urciuoli',
#  'Clarita Barron',
#  'Silvia Olson',
#  'Armand Arnold',
#  'Sueann Casciani',
#  'Jc Elliott',
#  'Kalet Eaton',
#  'Ottavia Abraham',
#  'Swanhild Cameron',
#  'Alessandrina Jollenbeck',
#  'Jamison Perona',
#  'Louis Justice',
#  'Pablo Sykes',
#  'Nek Blecher',
#  'Guadalupe Pannone',
#  'Ramona Berg',
#  'Gioconda Webster',
#  'George Bauers',
#  'Julian Maillot',
#  'Melusina Asti',
#  'Ornella Hester',
#  'Dione Gass',
#  'Konrad Damone',
#  'Walid Woods',
#  'Giana Blevins',
#  'Lino Pires',
#  'Helmina Mosco',
#  'Inaya Barton',
#  'Francesca Chambers',
#  'Kenisha Bergfalk',
#  'Ismael Sarrazin',
#  'Holger Vitiello',
#  'Nayla Melendez',
#  'Camila Sciarretta',
#  'Lucia Hatfield',
#  'Annetta Scholz',
#  'Demarcus Barthelemy',
#  'Clifton Garibaldi',
#  'Tobias Mcintyre',
#  'Lalie Tyler',
#  'Cristiano Everhart',
#  'Shirl Rochon',
#  'Treena Ciampa',
#  'Luther Leonard',
#  'Affonso Abraham',
#  'So Boilard',
#  'Luther Barberi',
#  'Leuther Webb',
#  'Abel Burke',
#  'Calogero Geiger',
#  'Nelson Lemire',
#  'Nadene Cartelli',
#  'Calvin Tate',
#  'Axel Watts',
#  'Alda Feigenbaum',
#  'Elena Shields',
#  'Circinus Odom',
#  'Marietta Holzmann',
#  'Peg Corriveau',
#  'Gregory Cianciolo',
#  'Nolhan Lindsey',
#  'Romero Blau',
#  'Genaro Larose',
#  'Oralee Garbarino',
#  'Karsten Riggs',
#  'Joris Cline',
#  'Tasha Holzknecht',
#  'Jarrett Beaumont',
#  'Laverne Maddalone',
#  'Imre Carlson',
#  'Angel Brennan',
#  'Jinny Michaud',
#  'Maryam Armellino',
#  'Lyle Massey',
#  'Peppe Pohl',
#  'Shakita Sabatier',
#  'Lynwood Bozza',
#  'Siglinde Flores',
#  'Jaden Castro',
#  'Bartolo Haupt',
#  'Venetta Perugini',
#  'Ellsworth Clements',
#  'Harbin Alston',
#  'Syrine Walter',
#  'Sansone Bisaillon',
#  'Shantay Fiori',
#  'Mary Prince',
#  'Catrin Ferguson',
#  'Gianpiero Samson',
#  'Robert Altieri',
#  'Yvone Capodanno',
#  'Lucetta Eichel',
#  'Jalisa Anastasi',
#  'Jessi Farley',
#  'Adolph Merrill',
#  'Riyad Holst',
#  'Donatien Lefrancois',
#  'Jere Evans',
#  'Xandi Glenn',
#  'Marianne Geiger',
#  'Alonzo Gautier',
#  'Santo Cornacchia',
#  'Aleida Robertson',
#  'Alexandra Nolan',
#  'Marina Habich',
#  'Agnella Cloutier',
#  'Loralee Nerone',
#  'Dot Moore',
#  'Wolf Morin',
#  'Ciel Augustin',
#  'Leontina Saucier',
#  'Kathern Rodriquez',
#  'Alder Dressler',
#  'Aroghetto Manza',
#  'Roberto Perry',
#  'Reena Shaw',
#  'Melina Abeln',
#  'Xavier Delahaye',
#  'Moses Cece',
#  'Sheilah Shaw',
#  'Daniela Rhodes',
#  'Viviana Belhumeur',
#  'Mireille Stanley',
#  'Lynetta Frank',
#  'Hermann Buckholtz',
#  'Leane Boulanger',
#  'Ugo Mammone',
#  'Gail Hewitt',
#  'Kermit Lowery',
#  'Alois Behrend',
#  'Bonito Bon',
#  'Jacinda Verde',
#  'Lloyd Holden',
#  'Kurigunde Wolfe',
#  'Marvin Hummel',
#  'Baiardo Maglione',
#  'Isaias Lyons',
#  'Johnnie Le',
#  'Walker Friedrich',
#  'Benedict Allen',
#  'Sung Jordan',
#  'Garfield Bonnard',
#  'Hansel Mecca',
#  'Emy Chapman',
#  'Lucetta Wilcox',
#  'Danial Hummel',
#  'Marion Ribeiro',
#  'Gilbert Spaziani',
#  'Genevra Bentley',
#  'Emilio Owen',
#  'Reid Borchard',
#  'Oscar Gallant',
#  'Titouan Reginato',
#  'Aniella Coleman',
#  'Laurena Ortiz',
#  'Helaine Carignan',
#  'Harold Vinci',
#  'Monte Dillon',
#  'Shondra Bach',
#  'Saul Fayolle',
#  'Etienne Buonopane',
#  'Beatrix Noble',
#  'Seema Cherry',
#  'Toby Haupt',
#  'Lamar Berger',
#  'Suzanne Paniccia',
#  'Bianka Massey',
#  'Tomika Andrews',
#  'Bertha Maurin',
#  'Nyla Mcconnell',
#  'Ronny Gotti',
#  'Rollin Magne',
#  'Anae Buzzeo',
#  'Giada Fisher',
#  'Cletus Hatfield',
#  'Jeffrey Gerber',
#  'Philomena Leduc',
#  'Bellissa Carpenter',
#  'Nadene Pittman',
#  'Nakita Jourdain',
#  'Alger Spatafore',
#  'Luna Gallegos',
#  'Rosanna Mcbride',
#  'Kali Haber',
#  'Medwin Lazzaro',
#  'Dany Floyd',
#  'Cristiana Stafford',
#  'Warner Hermann',
#  'Javier Pearson',
#  'Romano Whitehead',
#  'Marquis Dietrich',
#  'Donovan Filiatrault',
#  'Robert Lopardo',
#  'Anael Beck',
#  'Teofila Horn',
#  'Ishild Fusillo',
#  'Lilas Suarez',
#  'Beatrice Huffman',
#  'Bart Buhr',
#  'Sylvester Arnould',
#  'Joseph Berardinelli',
#  'Lucca Stafford',
#  'Malvina Faerber',
#  'Sydney Guillard',
#  'Julie Garavaglia',
#  'Raeann Atkins',
#  'Azucena Dresdner',
#  'Aminata Bonato',
#  'Mariya Mays',
#  'Trevor Prince',
#  'Lamont Ingersleben',
#  'Mirco Boisson',
#  'Jessica Camilli',
#  'Rodrigo Meadows',
#  'Barrett Mcclain',
#  'Rainer Jourdain',
#  'Edda Underwood',
#  'Tad Fleming',
#  'Lindsey Beck',
#  'Kirsten Poisson',
#  'Barney Morris',
#  'Kasi Merritt',
#  'Brunhilde Walter',
#  'Lilly Billet',
#  'Alfonzo Harris',
#  'Dorine Barrett',
#  'Soraya Boudet',
#  'Giambattista Mazzoni',
#  'Chanelle Hyde',
#  'Bradley Harrell',
#  'Minna Schuster',
#  'Ilyes Bellemare',
#  'Marsalis Colaianni',
#  'Darnell Goodman',
#  'Shay Daniel',
#  'Alessandro Correale',
#  'Natale Wallace',
#  'Michale Adenauer',
#  'Dietlinde Ayotte',
#  'Mikki Guyard',
#  'Alder Carnaghi',
#  'Nada Workman',
#  'Benvolio Howe',
#  'Burma Hintzen',
#  'Mirko Melchiori',
#  'Leny Harper',
#  'Scirocco Ellison',
#  'Buena Hellewege',
#  'Kanesha Correale',
#  'Renate Faulkner',
#  'Mohamed Gamble',
#  'Laronda Brossard',
#  'Derek Bresciani',
#  'Silvio Feld',
#  'Noah Peroni',
#  'Medard Andrews',
#  'Albane Tillman',
#  'Nathanial Heinrichs',
#  'Margeret Rocheleau',
#  'Alex Dominguez',
#  'Elario Avery',
#  'Delila Gros',
#  'Annalee Patel',
#  'Trudy Paoletta',
#  'Rayan Alston',
#  'Daniel Larson',
#  'Raelene Horowitz',
#  'Rolanda Aubry',
#  'Chevy Traino',
#  'Perry Knox',
#  'Shu Dennis',
#  'Grethe Derrick',
#  'Vadim Baudoin',
#  'Ruggero Tucker',
#  'Wen Voigt',
#  'Viktoria Verrier',
#  'Janna Rando',
#  'Isabella Salas',
#  'Katherin Bumgarner',
#  'Lamar Lemelin',
#  'Maribel Catone',
#  'Ezequiel Brandt',
#  'Willie Launay',
#  'Safa Torchia',
#  'Clara Larson',
#  'Williams Sargent',
#  'Cassondra Bret',
#  'Catrin Barbarino',
#  'Jasmine Conley',
#  'Keli Grosz',
#  'Elbert Corriveau',
#  'August Raffo',
#  'Albertina Francis',
#  'Sergio Jager',
#  'Dillon Guertin',
#  'Diedrich Colantuono',
#  'Zahra Briggs',
#  'Charlsie Landry',
#  'Jordon Cianci',
#  'Alvin Shaw',
#  'Iban Petersen',
#  'Ramiro Chevalier',
#  'Floyd Savoia',
#  'Nathalie Velez',
#  'Marianne Sweeney',
#  'Orabella Dahl',
#  'Maryanna Ferreira',
#  'Arnetta Sarra',
#  'Vonn Juarez',
#  'Lino Barrett',
#  'Simone Lang',
#  'Myron Carrere',
#  'Raleigh Marchini',
#  'Peter Guy',
#  'Nohlan Hubbard',
#  'Prima Beckert',
#  'Gwenn Lehoux',
#  'Louetta Andrews',
#  'Anton Wagner',
#  'Roman Eichel',
#  'Bianka Beaumont',
#  'Kathyrn Arata',
#  'Verona Weeks',
#  'Tao Becke',
#  'Herbert Costa',
#  'Antoine Stokes',
#  'Helmuth West',
#  'Amando Peters',
#  'Sidney Spezia',
#  'Elwanda Lopez',
#  'Achim Avila',
#  'Elias Giehl',
#  'Beltrano Brodeur',
#  'Loren Esposito',
#  'Mary Daniels',
#  'Medard Jordan',
#  'Joseph Favre',
#  'Ortensia Sodaro',
#  'Harley Watts',
#  'Carl Dohman',
#  'Lucia Danieli',
#  'Reatha Horton',
#  'Birgit Herzog',
#  'Leina Buratti',
#  'Cristen Stone',
#  'Maybell Foerstner',
#  'Walda Duhaime',
#  'Elyas Benigno',
#  'Antonietta Cervantes',
#  'Robbie Ayers',
#  'Kim Breiner',
#  'Arendt Boisson',
#  'Soline Manni',
#  'Nicostrato Nolan',
#  'Norris Haber',
#  'Kizzie Schmidt',
#  'Olivia Pata',
#  'Flavien Lopez',
#  'Vanna Boyer',
#  'Avery Hase',
#  'Micheal Perret',
#  'Sonje Sabatelli',
#  'Urbano Yates',
#  'Reita Schulz',
#  'Nils Crane',
#  'Calinda Flowers',
#  'Idell Avril',
#  'Jost Persichetti',
#  'Maribel Huff',
#  'Napoleone Trujillo',
#  'Marilou Richter',
#  'Carey Andolina',
#  'Carl Macias',
#  'Sylvana Derrick',
#  'Bryant Serres',
#  'Raffaela Allison',
#  'Remigio Lemelin',
#  'Cecil Camerino',
#  'Spencer Browning',
#  'Christof Graham',
#  'Quentin Brose',
#  'Federica Foulon',
#  'Hung Gengo',
#  'Shaina Beyersdorf',
#  'Pasquale Tran',
#  'Lorrine Cagnina',
#  'Rebbecca Copeland',
#  'Malte Douglas',
#  'Clint Clayton',
#  'Gretel Dunkle',
#  'Mehdi Boivin',
#  'Girolamo Casa',
#  'Delicia Cameron',
#  'Yoshie Estrada',
#  'Yasmin Dreher',
#  'Ilan Felix',
#  'Leandro Camerino',
#  'Erline Flores',
#  'Danae Gordon',
#  'Hahn Brose',
#  'Lison Mauger',
#  'Paolo Ciccarelli',
#  'Kirk Wheeler',
#  'Mataya Zanelli',
#  'Hubert Guy',
#  'Edwin Savage',
#  'Wulf Geissler',
#  'Erminia Saverino',
#  'Porter Nguyen',
#  'Eugene Mcmillan',
#  'Martin Justice',
#  'Alfred Seidel',
#  'Savannah Nieves',
#  'Collin Duke',
#  'Reda Brauer',
#  'Jutte Gobert',
#  'Tomi Mckinney',
#  'Kim Hofer',
#  'Conrad Dupuy',
#  'Axel Lona',
#  'Galileo Britt',
#  'Gustavo Hoffman',
#  'Madde Villard',
#  'Sebastiano Mellone',
#  'Nick Leonard',
#  'Nicholas Carey',
#  'Elise Janson',
#  'Isra Bordeleau',
#  'Fabia Margo',
#  'Uli Hintzen',
#  'Nelia Legendre',
#  'Bonito Albino',
#  'Harland Kent',
#  'Chan English',
#  'Diedrich Seidel',
#  'Amadeo Passamonte',
#  'Ava Lapierre',
#  'Cecilio Haney',
#  'Evan Hudson',
#  'Eugen Barreau',
#  'Didier Guidetti',
#  'Fiore Flynn',
#  'Audrea Mathews',
#  'Grover Zimmermann',
#  'Siegfried Bastien',
#  'Armand Uliano',
#  'Apollinare Hansen',
#  'Royce Fox',
#  'Anastacia Gabler',
#  'Gertrud White',
#  'Emeline Lupoli',
#  'Norma Gallegos',
#  'Walter Jordan',
#  'Bryanna Aue',
#  'Emmerich Gobeil',
#  'Lauren Mazzo',
#  'Severo Beasley',
#  'Delmar Owen',
#  'Swanhild Kirk',
#  'Ruggiero Geiszler',
#  'Dede Durocher',
#  'Gregory Raspa',
#  'Kim Ball',
#  'Lionel Montgomery',
#  'Emil Lane',
#  'Alessandrina Goebel',
#  'Leland Derasmo',
#  'Klara Reynolds',
#  'Del Acker',
#  'Angelena Nardone',
#  'Marcos Pomerleau',
#  'Burt Ellis',
#  'Jasmin Blanchard',
#  'Kamil Heinrich',
#  'Maurizia Ferrand',
#  'Jere Spaziano',
#  'Uschi Parks',
#  'Lucrecia Delgado',
#  'Moritz Cooper',
#  'Liborio Cabana',
#  'Deetta Passarelli',
#  'Antonio Compton',
#  'Nina Duncan',
#  'Francois Heinrichs',
#  'Serafino Carton',
#  'Emerson Ciminelli',
#  'Robin Lamb',
#  'Ulrika Yang',
#  'Nolann Klein',
#  'Annibale Pierre',
#  'Denis Racioppi',
#  'Arden Griffin',
#  'Ottila Bruce',
#  'Tancredo Dreschner',
#  'Carlos Fiocca',
#  'Xanthippe Barrett',
#  'Mayron Glenn',
#  'Aniello Brant',
#  'Willard Renard',
#  'Jodee Savelli',
#  'Robert Glover',
#  'Loretta Rutledge',
#  'Jerica Quentin',
#  'Vanna Winters',
#  'Mila Abraham',
#  'Maida Sergent',
#  'Belvedere Humphrey',
#  'Arletha Engel',
#  'Ernie Chiappini',
#  'Melyna Hutchinson',
#  'Annetta Andreas',
#  'Carson Quenneville',
#  'Lashon Patalano',
#  'Ilsa Patrick',
#  'Canon Wheeler',
#  'Russel Duriez',
#  'Isaias Cherico',
#  'Waldeburg Mills',
#  'Lilie Simpson',
#  'Floritzel Jollenbeck',
#  'Logan Desmarais',
#  'Peter Maldonado',
#  'Delano Molina',
#  'Rossella Thomas',
#  'Jeffrey Dupuy',
#  'Zenia Bizzaro',
#  'Janna Payne',
#  'Coco Grosse',
#  'Guy Peter',
#  'Parker Calandro',
#  'Sander Lott',
#  'Yael Villarreal',
#  'Mia Feigenbaum',
#  'Thomas Davi',
#  'Tobias Grant',
#  'Klarissa Carver',
#  'Cassi Serrano',
#  'Margrett Tierno',
#  'Hellmuth Warren',
#  'Sabri Knight',
#  'Uberta Doyle',
#  'Leida Buffo',
#  'Burt Colon',
#  'Sabine Velazquez',
#  'Ayman Bocker',
#  'Teofilo Alarie',
#  'Jere Armellino',
#  'Rudy Chase',
#  'Miles Copeland',
#  'Luigi Pasquarelli',
#  'Federico Odom',
#  'Medard Berg',
#  'Geron Pichette',
#  'Mariyah Romagnoli',
#  'Keneth Pacheco',
#  'Linda Baum',
#  'Zahra Rousseau',
#  'Biondello Mannella',
#  'Al Harris',
#  'Teodoro Rosa',
#  'Odilia Hofer',
#  'Romane Bruneau',
#  'Ruggerio Brizzi',
#  'Alwina Brune',
#  'Charlie Jomphe',
#  'Taddeo Ranallo',
#  'Boris Houston',
#  'Nicolaus Winkler',
#  'Nathanael Baudouin',
#  'Italo Cervelli',
#  'Jackie Robertson',
#  'Otis Hofmann',
#  'Joris Croteau',
#  'Geltrude Guidone',
#  'Christoper Baker',
#  'Wendell Joseph',
#  'Katinka Bader',
#  'Idris Duprat',
#  'Ping Wright',
#  'Margarett Downs',
#  'Dietlind Buhr',
#  'Verena Best',
#  'Thimeo Leduc',
#  'Santuzza Esposito',
#  'Jenice Fuller',
#  'Nathaniel Hendricks',
#  'Albert Kaiser',
#  'Tamara Tanguay',
#  'Carson Mcguire',
#  'Isaias Hutchinson',
#  'Milla Beckert',
#  'Donielle Angelo',
#  'Norberto Allen',
#  'Arminda Ratliff',
#  'Patrick Winkler',
#  'Hawa Beaudry',
#  'Marcoantonio Perretti',
#  'Edmund Miranda',
#  'Chet Rutledge',
#  'Sabina Buchholz',
#  'Noam Camus',
#  'Immaculata Vanni',
#  'Kathern Raymond',
#  'Kathyrn Peck',
#  'Hilda Blumstein',
#  'Massima Baldocchi',
#  'Lera Pearson',
#  'Alleen Ellison',
#  'Tobias Althaus',
#  'Kim Desbiens',
#  'Lucy Tringale',
#  'Dusti Sampson',
#  'Hyon Mcgowan',
#  'Benedikt Martin',
#  'Melina Montminy',
#  'Nerezza Bottino',
#  'Carter Washington',
#  'Lashawnda Bradshaw',
#  'Aldo Pohl',
#  'Gaston Terrier',
#  'Enric Pittman',
#  'Wonda Ayers',
#  'Yasuko Fabel',
#  'Fredrik Lacroix',
#  'Lucia Borgo',
#  'Donatello Gordon',
#  'Kraig Busch',
#  'Fiona Brando',
#  'Lisle Weaver',
#  'Alec Ebner',
#  'Andreas Rigal',
#  'Malone Trani',
#  'Daniela Kirkland',
#  'Avril Mcintosh',
#  'Clotilde Rodrigue',
#  'Wernher Carboni',
#  'Bruna Clements',
#  'Cody Feldt',
#  'Junita Neveu',
#  'Barbara Gagliano',
#  'Sherice Hellewege',
#  'Mitch Jalbert',
#  'Johannes Magistro',
#  'Nolann Foreman',
#  'Carline Goebel',
#  'Livia Phaneuf',
#  'Ottomar Foto',
#  'Deangela Schmidt',
#  'Bryant Borchard',
#  'Beatrix Vietti',
#  'Chaima Porter',
#  'Armani Wheeler',
#  'Min Schmidt',
#  'Randal Lacasse',
#  'Maya Cira',
#  'Milan Valencia',
#  'Rosa Glover',
#  'Erich Braun',
#  'Eusebio Barthelemy',
#  'Lara Buonopane',
#  'Anonciada Aguilar',
#  'Soraya Hudson',
#  'Renda Gorman',
#  'Anton Munier',
#  'Kiara Angelillo',
#  'Lucilla Black',
#  'Willian Hoover',
#  'Jenine Otto',
#  'Helga Dupre',
#  'Dorotea Cox',
#  'Gonzalo Hansen',
#  'Randell Abt',
#  'Leni Grimard',
#  'Fiammetta Huber',
#  'Larae Hildebrand',
#  'Annita Herve',
#  'Holger Tangredi',
#  'Lionel Langley',
#  'Venezio Ramos',
#  'Desmond Dreschner',
#  'Casey Villard',
#  'Felizitas Morano',
#  'Albane Jarvis',
#  'Paulita Salas',
#  'Delbert Baffa',
#  'Amy Underwood',
#  'Cristiana Griffith',
#  'Doyle Schmid',
#  'Reita Tomasso',
#  'Patrizia Hinton',
#  'Tatiana Castillo',
#  'Montrel Beckert',
#  'Shawanda Lindsey',
#  'Ulbrecht Holland',
#  'Kara Marchitelli',
#  'Else Beck',
#  'Tod Byrd',
#  'Liselotte Dittmar',
#  'Roque Lacoste',
#  'Maynard Townsend',
#  'Lucie Frost',
#  'Tristan Acker',
#  'Santo Drolet',
#  'Dewayne Pasqual',
#  'Maximino Small',
#  'Jonathan Faerber',
#  'Desmond Beauchamp',
#  'Laura Cassone',
#  'Suzi Chen',
#  'Norbert Avella',
#  'Milo Porter',
#  'Rainieri Ware',
#  'Rudolph Dresdner',
#  'Dierk Costanzo',
#  'Kayla Mueller',
#  'Heriberto Ahlers',
#  'Marceline Albert',
#  'Loretto Salas',
#  'Delila Lawrence',
#  'Federico Jager',
#  'Peter Fauteux',
#  'Marvin Calandra',
#  'Lucca Crosby',
#  'Keena Rollins',
#  'Edmund Baumann',
#  'Sara Charbonneau',
#  'Hortense Tangredi',
#  'Constanza Frost',
#  'Tanna Henson',
#  'Ute Favreau',
#  'Timeo Troncone',
#  'Montrel Ruiz',
#  'Lashaunda Battle',
#  'Alger Provencher',
#  'Teofilo Briggs',
#  'Rosia Newman',
#  'Dewitt Fleischer',
#  'Liselotte Desrochers',
#  'Yasmine Vitulli',
#  'Edda Alexander',
#  'Kim Young',
#  'Joyce Cilento',
#  'Luca Arnold',
#  'Yacine Gulla',
#  'Aemilio Hill',
#  'Carmelia Mayo',
#  'Dorothea Thompson',
#  'Zelie Moroni',
#  'Yuette Hines',
#  'Sergio Bambach',
#  'Otis Trottier',
#  'Elnora Naclerio',
#  'Lashell Pope',
#  'Emilie Schulze',
#  'Noel Rocher',
#  'Nario Barretto',
#  'Heidy Beasley',
#  ...]

# %%
# Extract the email from the backer_info column and add it as a new column called "email".
email = [re.findall("(?:\"email\":\s\")([a-zA-Z0-9]+\S[a-zA-Z]+\Scom)",x)[0] for x in backer_info["backer_info"]]
email
# Out:
# ['avincent@live.com',
#  'harnold@yandex.com',
#  'lgoulet@yandex.com',
#  'tbrunelli@outlook.com',
#  'lhunt@live.com',
#  'lhuber@live.com',
#  'emorin@live.com',
#  'atrani@live.com',
#  'iduke@outlook.com',
#  'lwright@live.com',
#  'ubecker@yahoo.com',
#  'haudy@gmail.com',
#  'bbonura@yahoo.com',
#  'mgarner@protonmail.com',
#  'kdunn@yahoo.com',
#  'aschreiber@yahoo.com',
#  'ivilleneuve@yahoo.com',
#  'abonadonna@yandex.com',
#  'respinoza@outlook.com',
#  'knash@protonmail.com',
#  'gjager@yahoo.com',
#  'vpaolella@gmail.com',
#  'javila@protonmail.com',
#  'gachterberg@live.com',
#  'tdion@gmail.com',
#  'tverno@yandex.com',
#  'mwaller@protonmail.com',
#  'hchen@yandex.com',
#  'tauer@yahoo.com',
#  'tjodoin@yandex.com',
#  'tcapri@live.com',
#  'wwalton@protonmail.com',
#  'jgill@yahoo.com',
#  'jdoyle@gmail.com',
#  'ldeliso@gmail.com',
#  'cvaldez@gmail.com',
#  'kbutler@yahoo.com',
#  'dweber@live.com',
#  'adelorme@outlook.com',
#  'dbernardi@yandex.com',
#  'creeves@gmail.com',
#  'mruiz@outlook.com',
#  'mduerr@live.com',
#  'jricco@live.com',
#  'omunoz@yahoo.com',
#  'ngensch@yandex.com',
#  'tlejeune@outlook.com',
#  'dlonardo@live.com',
#  'mwest@live.com',
#  'imays@yandex.com',
#  'mbrose@protonmail.com',
#  'ncoutant@gmail.com',
#  'abraun@live.com',
#  'aferre@gmail.com',
#  'blynch@outlook.com',
#  'aramsey@yahoo.com',
#  'cbeitel@gmail.com',
#  'dvernet@protonmail.com',
#  'cjones@protonmail.com',
#  'lhays@outlook.com',
#  'whermann@outlook.com',
#  'eblanc@protonmail.com',
#  'ecesare@protonmail.com',
#  'yhudson@protonmail.com',
#  'asalazar@gmail.com',
#  'lbeck@gmail.com',
#  'ccaillet@yandex.com',
#  'mmedici@gmail.com',
#  'dgamble@yahoo.com',
#  'rhildebrand@yahoo.com',
#  'hraffin@yahoo.com',
#  'arandall@outlook.com',
#  'sweber@yahoo.com',
#  'rrenault@outlook.com',
#  'zcianciola@yahoo.com',
#  'gpotts@gmail.com',
#  'bmarsh@live.com',
#  'jduerr@yahoo.com',
#  'mmorin@yahoo.com',
#  'lsavage@gmail.com',
#  'spatton@live.com',
#  'hhoch@outlook.com',
#  'sberthier@protonmail.com',
#  'etrani@protonmail.com',
#  'sdieter@yahoo.com',
#  'tgregoire@live.com',
#  'kcelano@yandex.com',
#  'sdecker@yahoo.com',
#  'skeller@outlook.com',
#  'kmichel@gmail.com',
#  'fungaro@yandex.com',
#  'ldejesus@yandex.com',
#  'dsuarez@yahoo.com',
#  'bbuchholz@live.com',
#  'wdickson@yandex.com',
#  'jdaugherty@gmail.com',
#  'ddressler@yahoo.com',
#  'cvillette@outlook.com',
#  'cnetti@outlook.com',
#  'ebutler@yahoo.com',
#  'amann@yahoo.com',
#  'grobert@protonmail.com',
#  'azezza@live.com',
#  'kcampbell@protonmail.com',
#  'lbrock@outlook.com',
#  'rlevasseur@gmail.com',
#  'jflowers@live.com',
#  'tbullock@yahoo.com',
#  'dgallois@outlook.com',
#  'rrichards@live.com',
#  'shoffman@outlook.com',
#  'lweber@live.com',
#  'slouvet@gmail.com',
#  'dpaola@outlook.com',
#  'idressler@protonmail.com',
#  'ekhan@outlook.com',
#  'ebonomo@yandex.com',
#  'agolden@yandex.com',
#  'acabrera@live.com',
#  'sfuhrmann@yahoo.com',
#  'sallard@yandex.com',
#  'kcaroselli@yandex.com',
#  'btaylor@outlook.com',
#  'mfischer@live.com',
#  'dhoffmann@yandex.com',
#  'ivallee@gmail.com',
#  'glindsey@protonmail.com',
#  'kbrennan@protonmail.com',
#  'jfux@gmail.com',
#  'jadam@protonmail.com',
#  'arosa@yahoo.com',
#  'dcabrera@live.com',
#  'ggeier@yahoo.com',
#  'dbeguin@yandex.com',
#  'ldamiani@outlook.com',
#  'bjenkins@protonmail.com',
#  'mcoffey@protonmail.com',
#  'hessert@gmail.com',
#  'pmarais@protonmail.com',
#  'bfulco@gmail.com',
#  'sburgess@yandex.com',
#  'psuarez@yahoo.com',
#  'mbiermann@gmail.com',
#  'abru@yahoo.com',
#  'jmagrino@live.com',
#  'rgould@gmail.com',
#  'ikline@live.com',
#  'rlehmann@gmail.com',
#  'acomte@yandex.com',
#  'egamble@yahoo.com',
#  'flott@yandex.com',
#  'mbeutel@gmail.com',
#  'enavarro@yahoo.com',
#  'mraffin@yahoo.com',
#  'scarr@outlook.com',
#  'xguy@protonmail.com',
#  'abecker@live.com',
#  'fdesautels@live.com',
#  'rmccray@gmail.com',
#  'lrush@protonmail.com',
#  'sholzknecht@protonmail.com',
#  'zverdier@yahoo.com',
#  'hbaldocchi@gmail.com',
#  'hbarnett@live.com',
#  'bedwards@yandex.com',
#  'lholst@live.com',
#  'zpruneau@gmail.com',
#  'depifano@protonmail.com',
#  'jbarrera@gmail.com',
#  'wburris@outlook.com',
#  'rdarras@gmail.com',
#  'eresta@outlook.com',
#  'jchen@outlook.com',
#  'kbutler@protonmail.com',
#  'afiedler@yandex.com',
#  'bpereira@live.com',
#  'tcarpinello@outlook.com',
#  'akaufman@outlook.com',
#  'mrowe@yahoo.com',
#  'bbellotti@yandex.com',
#  'bjenkins@outlook.com',
#  'qwashington@gmail.com',
#  'radam@live.com',
#  'pguilbaud@outlook.com',
#  'eforgione@gmail.com',
#  'rpotts@protonmail.com',
#  'severett@yahoo.com',
#  'sdesroches@yahoo.com',
#  'mbarrese@yandex.com',
#  'lroberts@protonmail.com',
#  'fmcneil@outlook.com',
#  'wdattoli@outlook.com',
#  'lstephens@protonmail.com',
#  'amoses@outlook.com',
#  'tacker@outlook.com',
#  'rbiron@outlook.com',
#  'ccappella@gmail.com',
#  'vhyde@live.com',
#  'ogwerder@yandex.com',
#  'ddemers@yahoo.com',
#  'aperagine@live.com',
#  'vwells@yandex.com',
#  'fhodges@yandex.com',
#  'dfiedler@yahoo.com',
#  'jveronesi@gmail.com',
#  'tcarver@gmail.com',
#  'meilerts@gmail.com',
#  'kpuech@protonmail.com',
#  'xpergola@yandex.com',
#  'afox@protonmail.com',
#  'wnazzaro@yahoo.com',
#  'adecker@yahoo.com',
#  'rschneider@live.com',
#  'dpruneau@outlook.com',
#  'memilio@gmail.com',
#  'estout@gmail.com',
#  'sdreher@yahoo.com',
#  'tbriere@outlook.com',
#  'eblack@yahoo.com',
#  'fburgstaller@outlook.com',
#  'jbenard@yandex.com',
#  'acurtis@live.com',
#  'kcampbell@protonmail.com',
#  'dgerst@protonmail.com',
#  'mbussa@yahoo.com',
#  'emccoy@live.com',
#  'twilder@yandex.com',
#  'abreitbarth@protonmail.com',
#  'dgaillard@live.com',
#  'cjoseph@live.com',
#  'lortega@yandex.com',
#  'bguay@yandex.com',
#  'jcastellucci@yahoo.com',
#  'jfreeman@live.com',
#  'lrobbins@live.com',
#  'cpetitjean@yandex.com',
#  'vvesco@live.com',
#  'chofmeister@protonmail.com',
#  'dmarques@yandex.com',
#  'lcarson@gmail.com',
#  'ameadows@gmail.com',
#  'abecke@yahoo.com',
#  'mbabin@outlook.com',
#  'purciuoli@yandex.com',
#  'cbarron@protonmail.com',
#  'solson@gmail.com',
#  'aarnold@live.com',
#  'scasciani@outlook.com',
#  'jelliott@yandex.com',
#  'keaton@outlook.com',
#  'oabraham@yandex.com',
#  'scameron@yandex.com',
#  'ajollenbeck@outlook.com',
#  'jperona@live.com',
#  'ljustice@yahoo.com',
#  'psykes@yandex.com',
#  'nblecher@yahoo.com',
#  'gpannone@outlook.com',
#  'rberg@yandex.com',
#  'gwebster@live.com',
#  'gbauers@yahoo.com',
#  'jmaillot@yandex.com',
#  'masti@yandex.com',
#  'ohester@live.com',
#  'dgass@yandex.com',
#  'kdamone@yandex.com',
#  'wwoods@protonmail.com',
#  'gblevins@protonmail.com',
#  'lpires@yandex.com',
#  'hmosco@outlook.com',
#  'ibarton@yandex.com',
#  'fchambers@protonmail.com',
#  'kbergfalk@outlook.com',
#  'isarrazin@live.com',
#  'hvitiello@protonmail.com',
#  'nmelendez@yahoo.com',
#  'csciarretta@yandex.com',
#  'lhatfield@gmail.com',
#  'ascholz@live.com',
#  'dbarthelemy@gmail.com',
#  'cgaribaldi@live.com',
#  'tmcintyre@gmail.com',
#  'ltyler@outlook.com',
#  'ceverhart@yandex.com',
#  'srochon@live.com',
#  'tciampa@yandex.com',
#  'lleonard@gmail.com',
#  'aabraham@outlook.com',
#  'sboilard@yandex.com',
#  'lbarberi@yahoo.com',
#  'lwebb@gmail.com',
#  'aburke@outlook.com',
#  'cgeiger@outlook.com',
#  'nlemire@yahoo.com',
#  'ncartelli@live.com',
#  'ctate@yandex.com',
#  'awatts@protonmail.com',
#  'afeigenbaum@live.com',
#  'eshields@outlook.com',
#  'codom@yahoo.com',
#  'mholzmann@yandex.com',
#  'pcorriveau@protonmail.com',
#  'gcianciolo@live.com',
#  'nlindsey@live.com',
#  'rblau@gmail.com',
#  'glarose@yahoo.com',
#  'ogarbarino@live.com',
#  'kriggs@live.com',
#  'jcline@yandex.com',
#  'tholzknecht@live.com',
#  'jbeaumont@yandex.com',
#  'lmaddalone@yahoo.com',
#  'icarlson@live.com',
#  'abrennan@live.com',
#  'jmichaud@live.com',
#  'marmellino@outlook.com',
#  'lmassey@yandex.com',
#  'ppohl@gmail.com',
#  'ssabatier@gmail.com',
#  'lbozza@yahoo.com',
#  'sflores@live.com',
#  'jcastro@outlook.com',
#  'bhaupt@outlook.com',
#  'vperugini@gmail.com',
#  'eclements@yahoo.com',
#  'halston@outlook.com',
#  'swalter@yahoo.com',
#  'sbisaillon@protonmail.com',
#  'sfiori@protonmail.com',
#  'mprince@protonmail.com',
#  'cferguson@gmail.com',
#  'gsamson@yandex.com',
#  'raltieri@protonmail.com',
#  'ycapodanno@live.com',
#  'leichel@protonmail.com',
#  'janastasi@yandex.com',
#  'jfarley@yahoo.com',
#  'amerrill@gmail.com',
#  'rholst@outlook.com',
#  'dlefrancois@yandex.com',
#  'jevans@outlook.com',
#  'xglenn@live.com',
#  'mgeiger@outlook.com',
#  'agautier@protonmail.com',
#  'scornacchia@yahoo.com',
#  'arobertson@yahoo.com',
#  'anolan@yandex.com',
#  'mhabich@protonmail.com',
#  'acloutier@yahoo.com',
#  'lnerone@live.com',
#  'dmoore@protonmail.com',
#  'wmorin@gmail.com',
#  'caugustin@yandex.com',
#  'lsaucier@live.com',
#  'krodriquez@live.com',
#  'adressler@outlook.com',
#  'amanza@yahoo.com',
#  'rperry@gmail.com',
#  'rshaw@protonmail.com',
#  'mabeln@yandex.com',
#  'xdelahaye@yahoo.com',
#  'mcece@protonmail.com',
#  'sshaw@yandex.com',
#  'drhodes@gmail.com',
#  'vbelhumeur@protonmail.com',
#  'mstanley@protonmail.com',
#  'lfrank@live.com',
#  'hbuckholtz@gmail.com',
#  'lboulanger@outlook.com',
#  'umammone@yahoo.com',
#  'ghewitt@outlook.com',
#  'klowery@gmail.com',
#  'abehrend@live.com',
#  'bbon@live.com',
#  'jverde@yahoo.com',
#  'lholden@outlook.com',
#  'kwolfe@protonmail.com',
#  'mhummel@yahoo.com',
#  'bmaglione@gmail.com',
#  'ilyons@yahoo.com',
#  'jle@protonmail.com',
#  'wfriedrich@live.com',
#  'ballen@protonmail.com',
#  'sjordan@gmail.com',
#  'gbonnard@yahoo.com',
#  'hmecca@outlook.com',
#  'echapman@gmail.com',
#  'lwilcox@outlook.com',
#  'dhummel@yahoo.com',
#  'mribeiro@gmail.com',
#  'gspaziani@gmail.com',
#  'gbentley@gmail.com',
#  'eowen@yahoo.com',
#  'rborchard@gmail.com',
#  'ogallant@live.com',
#  'treginato@live.com',
#  'acoleman@yandex.com',
#  'lortiz@live.com',
#  'hcarignan@live.com',
#  'hvinci@yandex.com',
#  'mdillon@yandex.com',
#  'sbach@protonmail.com',
#  'sfayolle@yahoo.com',
#  'ebuonopane@live.com',
#  'bnoble@protonmail.com',
#  'scherry@protonmail.com',
#  'thaupt@gmail.com',
#  'lberger@yahoo.com',
#  'spaniccia@gmail.com',
#  'bmassey@yandex.com',
#  'tandrews@protonmail.com',
#  'bmaurin@protonmail.com',
#  'nmcconnell@outlook.com',
#  'rgotti@gmail.com',
#  'rmagne@yahoo.com',
#  'abuzzeo@protonmail.com',
#  'gfisher@protonmail.com',
#  'chatfield@yandex.com',
#  'jgerber@yahoo.com',
#  'pleduc@yandex.com',
#  'bcarpenter@yahoo.com',
#  'npittman@yahoo.com',
#  'njourdain@live.com',
#  'aspatafore@yahoo.com',
#  'lgallegos@live.com',
#  'rmcbride@yahoo.com',
#  'khaber@outlook.com',
#  'mlazzaro@live.com',
#  'dfloyd@gmail.com',
#  'cstafford@yahoo.com',
#  'whermann@protonmail.com',
#  'jpearson@yahoo.com',
#  'rwhitehead@protonmail.com',
#  'mdietrich@protonmail.com',
#  'dfiliatrault@yandex.com',
#  'rlopardo@live.com',
#  'abeck@live.com',
#  'thorn@protonmail.com',
#  'ifusillo@outlook.com',
#  'lsuarez@yandex.com',
#  'bhuffman@protonmail.com',
#  'bbuhr@yahoo.com',
#  'sarnould@gmail.com',
#  'jberardinelli@protonmail.com',
#  'lstafford@yandex.com',
#  'mfaerber@gmail.com',
#  'sguillard@gmail.com',
#  'jgaravaglia@yandex.com',
#  'ratkins@protonmail.com',
#  'adresdner@yandex.com',
#  'abonato@protonmail.com',
#  'mmays@gmail.com',
#  'tprince@yahoo.com',
#  'lingersleben@yandex.com',
#  'mboisson@protonmail.com',
#  'jcamilli@protonmail.com',
#  'rmeadows@live.com',
#  'bmcclain@yahoo.com',
#  'rjourdain@yahoo.com',
#  'eunderwood@live.com',
#  'tfleming@yandex.com',
#  'lbeck@live.com',
#  'kpoisson@yahoo.com',
#  'bmorris@protonmail.com',
#  'kmerritt@live.com',
#  'bwalter@gmail.com',
#  'lbillet@gmail.com',
#  'aharris@yahoo.com',
#  'dbarrett@gmail.com',
#  'sboudet@protonmail.com',
#  'gmazzoni@gmail.com',
#  'chyde@protonmail.com',
#  'bharrell@yandex.com',
#  'mschuster@gmail.com',
#  'ibellemare@protonmail.com',
#  'mcolaianni@yahoo.com',
#  'dgoodman@live.com',
#  'sdaniel@yandex.com',
#  'acorreale@yandex.com',
#  'nwallace@outlook.com',
#  'madenauer@protonmail.com',
#  'dayotte@yahoo.com',
#  'mguyard@outlook.com',
#  'acarnaghi@yandex.com',
#  'nworkman@yahoo.com',
#  'bhowe@gmail.com',
#  'bhintzen@live.com',
#  'mmelchiori@live.com',
#  'lharper@outlook.com',
#  'sellison@yahoo.com',
#  'bhellewege@yahoo.com',
#  'kcorreale@live.com',
#  'rfaulkner@outlook.com',
#  'mgamble@live.com',
#  'lbrossard@protonmail.com',
#  'dbresciani@outlook.com',
#  'sfeld@live.com',
#  'nperoni@outlook.com',
#  'mandrews@gmail.com',
#  'atillman@yahoo.com',
#  'nheinrichs@protonmail.com',
#  'mrocheleau@protonmail.com',
#  'adominguez@yandex.com',
#  'eavery@yahoo.com',
#  'dgros@yahoo.com',
#  'apatel@protonmail.com',
#  'tpaoletta@gmail.com',
#  'ralston@yahoo.com',
#  'dlarson@yahoo.com',
#  'rhorowitz@outlook.com',
#  'raubry@gmail.com',
#  'ctraino@outlook.com',
#  'pknox@gmail.com',
#  'sdennis@gmail.com',
#  'gderrick@live.com',
#  'vbaudoin@yahoo.com',
#  'rtucker@gmail.com',
#  'wvoigt@outlook.com',
#  'vverrier@yandex.com',
#  'jrando@protonmail.com',
#  'isalas@yandex.com',
#  'kbumgarner@live.com',
#  'llemelin@yahoo.com',
#  'mcatone@yandex.com',
#  'ebrandt@outlook.com',
#  'wlaunay@yandex.com',
#  'storchia@yahoo.com',
#  'clarson@yahoo.com',
#  'wsargent@outlook.com',
#  'cbret@outlook.com',
#  'cbarbarino@gmail.com',
#  'jconley@gmail.com',
#  'kgrosz@gmail.com',
#  'ecorriveau@protonmail.com',
#  'araffo@outlook.com',
#  'afrancis@gmail.com',
#  'sjager@live.com',
#  'dguertin@live.com',
#  'dcolantuono@protonmail.com',
#  'zbriggs@live.com',
#  'clandry@outlook.com',
#  'jcianci@protonmail.com',
#  'ashaw@yandex.com',
#  'ipetersen@gmail.com',
#  'rchevalier@yahoo.com',
#  'fsavoia@protonmail.com',
#  'nvelez@yandex.com',
#  'msweeney@gmail.com',
#  'odahl@gmail.com',
#  'mferreira@outlook.com',
#  'asarra@yahoo.com',
#  'vjuarez@protonmail.com',
#  'lbarrett@live.com',
#  'slang@yandex.com',
#  'mcarrere@outlook.com',
#  'rmarchini@protonmail.com',
#  'pguy@live.com',
#  'nhubbard@outlook.com',
#  'pbeckert@gmail.com',
#  'glehoux@outlook.com',
#  'landrews@yandex.com',
#  'awagner@yahoo.com',
#  'reichel@outlook.com',
#  'bbeaumont@live.com',
#  'karata@outlook.com',
#  'vweeks@protonmail.com',
#  'tbecke@gmail.com',
#  'hcosta@yandex.com',
#  'astokes@protonmail.com',
#  'hwest@gmail.com',
#  'apeters@yahoo.com',
#  'sspezia@gmail.com',
#  'elopez@live.com',
#  'aavila@gmail.com',
#  'egiehl@gmail.com',
#  'bbrodeur@outlook.com',
#  'lesposito@live.com',
#  'mdaniels@outlook.com',
#  'mjordan@outlook.com',
#  'jfavre@yandex.com',
#  'osodaro@yahoo.com',
#  'hwatts@outlook.com',
#  'cdohman@gmail.com',
#  'ldanieli@live.com',
#  'rhorton@protonmail.com',
#  'bherzog@protonmail.com',
#  'lburatti@gmail.com',
#  'cstone@protonmail.com',
#  'mfoerstner@protonmail.com',
#  'wduhaime@outlook.com',
#  'ebenigno@live.com',
#  'acervantes@gmail.com',
#  'rayers@protonmail.com',
#  'kbreiner@gmail.com',
#  'aboisson@protonmail.com',
#  'smanni@yahoo.com',
#  'nnolan@protonmail.com',
#  'nhaber@gmail.com',
#  'kschmidt@protonmail.com',
#  'opata@outlook.com',
#  'flopez@live.com',
#  'vboyer@protonmail.com',
#  'ahase@outlook.com',
#  'mperret@gmail.com',
#  'ssabatelli@outlook.com',
#  'uyates@yahoo.com',
#  'rschulz@protonmail.com',
#  'ncrane@protonmail.com',
#  'cflowers@live.com',
#  'iavril@gmail.com',
#  'jpersichetti@yandex.com',
#  'mhuff@outlook.com',
#  'ntrujillo@gmail.com',
#  'mrichter@live.com',
#  'candolina@protonmail.com',
#  'cmacias@gmail.com',
#  'sderrick@yahoo.com',
#  'bserres@live.com',
#  'rallison@yahoo.com',
#  'rlemelin@live.com',
#  'ccamerino@live.com',
#  'sbrowning@live.com',
#  'cgraham@gmail.com',
#  'qbrose@yandex.com',
#  'ffoulon@protonmail.com',
#  'hgengo@gmail.com',
#  'sbeyersdorf@outlook.com',
#  'ptran@live.com',
#  'lcagnina@yahoo.com',
#  'rcopeland@protonmail.com',
#  'mdouglas@yandex.com',
#  'cclayton@live.com',
#  'gdunkle@gmail.com',
#  'mboivin@protonmail.com',
#  'gcasa@protonmail.com',
#  'dcameron@live.com',
#  'yestrada@yandex.com',
#  'ydreher@outlook.com',
#  'ifelix@outlook.com',
#  'lcamerino@protonmail.com',
#  'eflores@protonmail.com',
#  'dgordon@live.com',
#  'hbrose@protonmail.com',
#  'lmauger@outlook.com',
#  'pciccarelli@protonmail.com',
#  'kwheeler@live.com',
#  'mzanelli@yahoo.com',
#  'hguy@protonmail.com',
#  'esavage@yahoo.com',
#  'wgeissler@outlook.com',
#  'esaverino@outlook.com',
#  'pnguyen@yandex.com',
#  'emcmillan@yandex.com',
#  'mjustice@yandex.com',
#  'aseidel@yahoo.com',
#  'snieves@protonmail.com',
#  'cduke@yandex.com',
#  'rbrauer@yahoo.com',
#  'jgobert@outlook.com',
#  'tmckinney@outlook.com',
#  'khofer@outlook.com',
#  'cdupuy@live.com',
#  'alona@gmail.com',
#  'gbritt@outlook.com',
#  'ghoffman@gmail.com',
#  'mvillard@yandex.com',
#  'smellone@yandex.com',
#  'nleonard@outlook.com',
#  'ncarey@live.com',
#  'ejanson@protonmail.com',
#  'ibordeleau@gmail.com',
#  'fmargo@outlook.com',
#  'uhintzen@protonmail.com',
#  'nlegendre@protonmail.com',
#  'balbino@protonmail.com',
#  'hkent@yahoo.com',
#  'cenglish@yahoo.com',
#  'dseidel@yandex.com',
#  'apassamonte@yandex.com',
#  'alapierre@yahoo.com',
#  'chaney@outlook.com',
#  'ehudson@yahoo.com',
#  'ebarreau@outlook.com',
#  'dguidetti@yahoo.com',
#  'fflynn@live.com',
#  'amathews@yahoo.com',
#  'gzimmermann@outlook.com',
#  'sbastien@protonmail.com',
#  'auliano@outlook.com',
#  'ahansen@protonmail.com',
#  'rfox@outlook.com',
#  'agabler@gmail.com',
#  'gwhite@protonmail.com',
#  'elupoli@yahoo.com',
#  'ngallegos@yahoo.com',
#  'wjordan@live.com',
#  'baue@protonmail.com',
#  'egobeil@protonmail.com',
#  'lmazzo@live.com',
#  'sbeasley@yahoo.com',
#  'dowen@protonmail.com',
#  'skirk@outlook.com',
#  'rgeiszler@live.com',
#  'ddurocher@gmail.com',
#  'graspa@yahoo.com',
#  'kball@protonmail.com',
#  'lmontgomery@gmail.com',
#  'elane@protonmail.com',
#  'agoebel@live.com',
#  'lderasmo@yandex.com',
#  'kreynolds@live.com',
#  'dacker@protonmail.com',
#  'anardone@gmail.com',
#  'mpomerleau@protonmail.com',
#  'bellis@yahoo.com',
#  'jblanchard@yandex.com',
#  'kheinrich@yahoo.com',
#  'mferrand@outlook.com',
#  'jspaziano@yandex.com',
#  'uparks@yahoo.com',
#  'ldelgado@protonmail.com',
#  'mcooper@protonmail.com',
#  'lcabana@protonmail.com',
#  'dpassarelli@live.com',
#  'acompton@yahoo.com',
#  'nduncan@yandex.com',
#  'fheinrichs@yandex.com',
#  'scarton@protonmail.com',
#  'eciminelli@live.com',
#  'rlamb@protonmail.com',
#  'uyang@yahoo.com',
#  'nklein@outlook.com',
#  'apierre@outlook.com',
#  'dracioppi@live.com',
#  'agriffin@yahoo.com',
#  'obruce@yahoo.com',
#  'tdreschner@yahoo.com',
#  'cfiocca@yandex.com',
#  'xbarrett@gmail.com',
#  'mglenn@protonmail.com',
#  'abrant@protonmail.com',
#  'wrenard@live.com',
#  'jsavelli@protonmail.com',
#  'rglover@yahoo.com',
#  'lrutledge@protonmail.com',
#  'jquentin@live.com',
#  'vwinters@yandex.com',
#  'mabraham@gmail.com',
#  'msergent@outlook.com',
#  'bhumphrey@protonmail.com',
#  'aengel@outlook.com',
#  'echiappini@protonmail.com',
#  'mhutchinson@yahoo.com',
#  'aandreas@outlook.com',
#  'cquenneville@live.com',
#  'lpatalano@protonmail.com',
#  'ipatrick@live.com',
#  'cwheeler@live.com',
#  'rduriez@outlook.com',
#  'icherico@yahoo.com',
#  'wmills@gmail.com',
#  'lsimpson@yandex.com',
#  'fjollenbeck@yandex.com',
#  'ldesmarais@yandex.com',
#  'pmaldonado@live.com',
#  'dmolina@yandex.com',
#  'rthomas@yahoo.com',
#  'jdupuy@live.com',
#  'zbizzaro@live.com',
#  'jpayne@yahoo.com',
#  'cgrosse@protonmail.com',
#  'gpeter@outlook.com',
#  'pcalandro@protonmail.com',
#  'slott@outlook.com',
#  'yvillarreal@yandex.com',
#  'mfeigenbaum@gmail.com',
#  'tdavi@yahoo.com',
#  'tgrant@gmail.com',
#  'kcarver@protonmail.com',
#  'cserrano@outlook.com',
#  'mtierno@yahoo.com',
#  'hwarren@yandex.com',
#  'sknight@yahoo.com',
#  'udoyle@protonmail.com',
#  'lbuffo@yandex.com',
#  'bcolon@gmail.com',
#  'svelazquez@yandex.com',
#  'abocker@gmail.com',
#  'talarie@gmail.com',
#  'jarmellino@yahoo.com',
#  'rchase@gmail.com',
#  'mcopeland@yahoo.com',
#  'lpasquarelli@gmail.com',
#  'fodom@protonmail.com',
#  'mberg@protonmail.com',
#  'gpichette@yahoo.com',
#  'mromagnoli@yandex.com',
#  'kpacheco@outlook.com',
#  'lbaum@yandex.com',
#  'zrousseau@gmail.com',
#  'bmannella@live.com',
#  'aharris@protonmail.com',
#  'trosa@yahoo.com',
#  'ohofer@yahoo.com',
#  'rbruneau@protonmail.com',
#  'rbrizzi@outlook.com',
#  'abrune@outlook.com',
#  'cjomphe@gmail.com',
#  'tranallo@outlook.com',
#  'bhouston@outlook.com',
#  'nwinkler@protonmail.com',
#  'nbaudouin@gmail.com',
#  'icervelli@live.com',
#  'jrobertson@yandex.com',
#  'ohofmann@yahoo.com',
#  'jcroteau@yahoo.com',
#  'gguidone@protonmail.com',
#  'cbaker@yahoo.com',
#  'wjoseph@outlook.com',
#  'kbader@yahoo.com',
#  'iduprat@gmail.com',
#  'pwright@yahoo.com',
#  'mdowns@yahoo.com',
#  'dbuhr@outlook.com',
#  'vbest@outlook.com',
#  'tleduc@yahoo.com',
#  'sesposito@outlook.com',
#  'jfuller@gmail.com',
#  'nhendricks@yahoo.com',
#  'akaiser@outlook.com',
#  'ttanguay@yandex.com',
#  'cmcguire@yandex.com',
#  'ihutchinson@outlook.com',
#  'mbeckert@protonmail.com',
#  'dangelo@yahoo.com',
#  'nallen@protonmail.com',
#  'aratliff@live.com',
#  'pwinkler@gmail.com',
#  'hbeaudry@gmail.com',
#  'mperretti@live.com',
#  'emiranda@yahoo.com',
#  'crutledge@yandex.com',
#  'sbuchholz@outlook.com',
#  'ncamus@outlook.com',
#  'ivanni@yandex.com',
#  'kraymond@live.com',
#  'kpeck@live.com',
#  'hblumstein@protonmail.com',
#  'mbaldocchi@protonmail.com',
#  'lpearson@protonmail.com',
#  'aellison@live.com',
#  'talthaus@outlook.com',
#  'kdesbiens@yahoo.com',
#  'ltringale@gmail.com',
#  'dsampson@outlook.com',
#  'hmcgowan@outlook.com',
#  'bmartin@outlook.com',
#  'mmontminy@yandex.com',
#  'nbottino@yandex.com',
#  'cwashington@yahoo.com',
#  'lbradshaw@yandex.com',
#  'apohl@yandex.com',
#  'gterrier@protonmail.com',
#  'epittman@live.com',
#  'wayers@yahoo.com',
#  'yfabel@yandex.com',
#  'flacroix@live.com',
#  'lborgo@protonmail.com',
#  'dgordon@protonmail.com',
#  'kbusch@live.com',
#  'fbrando@protonmail.com',
#  'lweaver@live.com',
#  'aebner@yahoo.com',
#  'arigal@yahoo.com',
#  'mtrani@gmail.com',
#  'dkirkland@outlook.com',
#  'amcintosh@protonmail.com',
#  'crodrigue@live.com',
#  'wcarboni@yandex.com',
#  'bclements@outlook.com',
#  'cfeldt@yandex.com',
#  'jneveu@outlook.com',
#  'bgagliano@live.com',
#  'shellewege@yahoo.com',
#  'mjalbert@live.com',
#  'jmagistro@yandex.com',
#  'nforeman@gmail.com',
#  'cgoebel@yandex.com',
#  'lphaneuf@outlook.com',
#  'ofoto@yandex.com',
#  'dschmidt@gmail.com',
#  'bborchard@yahoo.com',
#  'bvietti@gmail.com',
#  'cporter@gmail.com',
#  'awheeler@yahoo.com',
#  'mschmidt@yandex.com',
#  'rlacasse@yahoo.com',
#  'mcira@yandex.com',
#  'mvalencia@outlook.com',
#  'rglover@yandex.com',
#  'ebraun@yandex.com',
#  'ebarthelemy@outlook.com',
#  'lbuonopane@outlook.com',
#  'aaguilar@yandex.com',
#  'shudson@gmail.com',
#  'rgorman@outlook.com',
#  'amunier@yandex.com',
#  'kangelillo@protonmail.com',
#  'lblack@outlook.com',
#  'whoover@yahoo.com',
#  'jotto@live.com',
#  'hdupre@live.com',
#  'dcox@outlook.com',
#  'ghansen@outlook.com',
#  'rabt@outlook.com',
#  'lgrimard@gmail.com',
#  'fhuber@outlook.com',
#  'lhildebrand@outlook.com',
#  'aherve@yandex.com',
#  'htangredi@yandex.com',
#  'llangley@yandex.com',
#  'vramos@yandex.com',
#  'ddreschner@protonmail.com',
#  'cvillard@yandex.com',
#  'fmorano@yahoo.com',
#  'ajarvis@protonmail.com',
#  'psalas@outlook.com',
#  'dbaffa@outlook.com',
#  'aunderwood@yandex.com',
#  'cgriffith@gmail.com',
#  'dschmid@live.com',
#  'rtomasso@yahoo.com',
#  'phinton@live.com',
#  'tcastillo@yahoo.com',
#  'mbeckert@yandex.com',
#  'slindsey@gmail.com',
#  'uholland@live.com',
#  'kmarchitelli@yandex.com',
#  'ebeck@protonmail.com',
#  'tbyrd@protonmail.com',
#  'ldittmar@yandex.com',
#  'rlacoste@live.com',
#  'mtownsend@yahoo.com',
#  'lfrost@yahoo.com',
#  'tacker@gmail.com',
#  'sdrolet@outlook.com',
#  'dpasqual@live.com',
#  'msmall@yahoo.com',
#  'jfaerber@yahoo.com',
#  'dbeauchamp@protonmail.com',
#  'lcassone@yahoo.com',
#  'schen@protonmail.com',
#  'navella@yahoo.com',
#  'mporter@gmail.com',
#  'rware@yahoo.com',
#  'rdresdner@outlook.com',
#  'dcostanzo@yahoo.com',
#  'kmueller@live.com',
#  'hahlers@protonmail.com',
#  'malbert@gmail.com',
#  'lsalas@yandex.com',
#  'dlawrence@gmail.com',
#  'fjager@live.com',
#  'pfauteux@yahoo.com',
#  'mcalandra@yandex.com',
#  'lcrosby@gmail.com',
#  'krollins@yandex.com',
#  'ebaumann@yandex.com',
#  'scharbonneau@protonmail.com',
#  'htangredi@protonmail.com',
#  'cfrost@yahoo.com',
#  'thenson@yandex.com',
#  'ufavreau@yahoo.com',
#  'ttroncone@live.com',
#  'mruiz@protonmail.com',
#  'lbattle@outlook.com',
#  'aprovencher@yandex.com',
#  'tbriggs@protonmail.com',
#  'rnewman@protonmail.com',
#  'dfleischer@protonmail.com',
#  'ldesrochers@outlook.com',
#  'yvitulli@gmail.com',
#  'ealexander@outlook.com',
#  'kyoung@yahoo.com',
#  'jcilento@protonmail.com',
#  'larnold@outlook.com',
#  'ygulla@outlook.com',
#  'ahill@protonmail.com',
#  'cmayo@yandex.com',
#  'dthompson@live.com',
#  'zmoroni@outlook.com',
#  'yhines@protonmail.com',
#  'sbambach@outlook.com',
#  'otrottier@outlook.com',
#  'enaclerio@live.com',
#  'lpope@outlook.com',
#  'eschulze@outlook.com',
#  'nrocher@outlook.com',
#  'nbarretto@outlook.com',
#  'hbeasley@live.com',
#  ...]

# %%
# Create a new DataFrame with the appropriate columns.
data = [backer_id, cf_id, name,email]
backer_info_df = pd.DataFrame(data).T
backer_info_df.columns = ["backer_id", "cf_id", "name", "email"]
backer_info_df
# Out:
#      backer_id cf_id              name                  email
# 0        av166   968    Angelo Vincent      avincent@live.com
# 1        ha127   563     Hubert Arnold     harnold@yandex.com
# 2        lg794    65      Loris Goulet     lgoulet@yandex.com
# 3        tb566   563  Teodora Brunelli  tbrunelli@outlook.com
# 4        lh506   563        Lexie Hunt         lhunt@live.com
# ...        ...   ...               ...                    ...
# 8170     st581    65   Serita Thebault   sthebault@yandex.com
# 8171     gf637   563   Glenn Foerstner   gfoerstner@yahoo.com
# 8172     rc983  1114       Robt Collin    rcollin@outlook.com
# 8173     cz381    65      Corina Zappa     czappa@outlook.com
# 8174     fg535    65     Freeman Gibbs     fgibbs@outlook.com
#
# [8175 rows x 4 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
# backer_info_df.to_csv('Resources/backers_data.csv', encoding = 'utf8')

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backers_info_df.dtypes
# Out:
# backer_id    object
# cf_id         int64
# name         object
# email        object
# dtype: object

# %%
# Convert cf_id to an integer if necessary.

#note backer_info_df is df made from regex
backer_info_df["cf_id"] = pd.to_numeric(backer_info_df["cf_id"])
backer_info_df.dtypes
# Out:
# backer_id    object
# cf_id         int64
# name         object
# email        object
# dtype: object

# %%
# Split the "name" column into "first_name" and "last_name" columns.
backers_info_df[["first_name","last_name"]] = backers_info_df["name"].str.split(" ", n = 1, expand = True)
backers_info_df.head(10)
# Out:
#   backer_id  cf_id              name                  email first_name  \
# 0     av166    968    Angelo Vincent      avincent@live.com     Angelo
# 1     ha127    563     Hubert Arnold     harnold@yandex.com     Hubert
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com      Loris
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com    Teodora
# 4     lh506    563        Lexie Hunt         lhunt@live.com      Lexie
# 5     lh382    563     Lambert Huber        lhuber@live.com    Lambert
# 6     em444    563        Emmy Morin        emorin@live.com       Emmy
# 7     at582   1572     Armonda Trani        atrani@live.com    Armonda
# 8     id772   1911        Ilana Duke      iduke@outlook.com      Ilana
# 9     lw275     65     Leigha Wright       lwright@live.com     Leigha
#
#   last_name
# 0   Vincent
# 1    Arnold
# 2    Goulet
# 3  Brunelli
# 4      Hunt
# 5     Huber
# 6     Morin
# 7     Trani
# 8      Duke
# 9    Wright

# %%
#  Drop the name column
backers_info_df.drop(["name"], axis = 1)

# Reorder the columns
reorder = ["backer_id", "cf_id", "first_name", "last_name", "email"]
backers_info_df = backers_info_df[reorder]
backers_info_df
# Out:
#      backer_id  cf_id first_name  last_name                  email
# 0        av166    968     Angelo    Vincent      avincent@live.com
# 1        ha127    563     Hubert     Arnold     harnold@yandex.com
# 2        lg794     65      Loris     Goulet     lgoulet@yandex.com
# 3        tb566    563    Teodora   Brunelli  tbrunelli@outlook.com
# 4        lh506    563      Lexie       Hunt         lhunt@live.com
# ...        ...    ...        ...        ...                    ...
# 8170     st581     65     Serita   Thebault   sthebault@yandex.com
# 8171     gf637    563      Glenn  Foerstner   gfoerstner@yahoo.com
# 8172     rc983   1114       Robt     Collin    rcollin@outlook.com
# 8173     cz381     65     Corina      Zappa     czappa@outlook.com
# 8174     fg535     65    Freeman      Gibbs     fgibbs@outlook.com
#
# [8175 rows x 5 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_info_df.to_csv("Resources/backers.csv", encoding = 'utf8')
